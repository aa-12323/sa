# %%
import pandas as pd

def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
cluster=pd.read_pickle('/home/cz136/project/sa/data/cluster.pkl')
shape=pd.read_pickle('/home/cz136/project/sa/data/shape.pkl')

# %%
print(cluster.columns.to_numpy())
# Out:
# [('Band', 'g', 'MODEL_MAG') ('Band', 'g', 'MODEL_MAGERR')
#  ('Band', 'g', 'MAG_LAMBDA_ERR') ('Band', 'r', 'MODEL_MAG')
#  ('Band', 'r', 'MODEL_MAGERR') ('Band', 'r', 'MAG_LAMBDA_ERR')
#  ('Band', 'i', 'MODEL_MAG') ('Band', 'i', 'MODEL_MAGERR')
#  ('Band', 'i', 'MAG_LAMBDA_ERR') ('Band', 'z', 'MODEL_MAG')
#  ('Band', 'z', 'MODEL_MAGERR') ('Band', 'z', 'MAG_LAMBDA_ERR')
#  ('PZ', 'pz1', 'PZBINS') ('PZ', 'pz2', 'PZBINS') ('PZ', 'pz3', 'PZBINS')
#  ('PZ', 'pz4', 'PZBINS') ('PZ', 'pz5', 'PZBINS') ('PZ', 'pz6', 'PZBINS')
#  ('PZ', 'pz7', 'PZBINS') ('PZ', 'pz8', 'PZBINS') ('PZ', 'pz9', 'PZBINS')
#  ('PZ', 'pz10', 'PZBINS') ('PZ', 'pz11', 'PZBINS')
#  ('PZ', 'pz12', 'PZBINS') ('PZ', 'pz13', 'PZBINS')
#  ('PZ', 'pz14', 'PZBINS') ('PZ', 'pz15', 'PZBINS')
#  ('PZ', 'pz16', 'PZBINS') ('PZ', 'pz17', 'PZBINS')
#  ('PZ', 'pz18', 'PZBINS') ('PZ', 'pz19', 'PZBINS')
#  ('PZ', 'pz20', 'PZBINS') ('PZ', 'pz21', 'PZBINS') ('PZ', 'pz1', 'PZ')
#  ('PZ', 'pz2', 'PZ') ('PZ', 'pz3', 'PZ') ('PZ', 'pz4', 'PZ')
# ...

# %%
cluster
# Out:
# Type                           Band                                         \
# Kind                              g                                      r
# Data                      MODEL_MAG MODEL_MAGERR MAG_LAMBDA_ERR  MODEL_MAG
# (All, All, MEM_MATCH_ID)
# 1                         20.175312     0.016915       0.001283  18.321383
# 2                         19.667797     0.006787       0.000274  17.954527
# 3                         19.575390     0.009780       0.001122  17.845314
# 4                         18.861450     0.006732       0.000276  17.305017
# 5                         19.863644     0.008220       0.000520  18.214876
# ...                             ...          ...            ...        ...
# 33538                     22.477217     0.046772       0.008581  20.689310
# 33839                     23.217733     0.068689       0.019012  21.364346
# 36361                     21.913805     0.055043       0.012630  20.404688
# ...

# %%
print(shape.columns.to_numpy())
# Out:
# [('All', 'MEM_MATCH_ID') ('All', 'Z') ('All', 'RA') ('All', 'DEC')
#  ('All', 'R') ('All', 'P') ('All', 'PFREE') ('All', 'THETA_I')
#  ('All', 'THETA_R') ('All', 'REFMAG_FIT') ('All', 'REFMAG_FIT_E')
#  ('All', 'REFMAG') ('All', 'REFMAG_ERR') ('All', 'ZRED') ('All', 'ZRED_E')
#  ('All', 'ZRED2') ('All', 'ZRED2_E') ('All', 'CHISQ') ('All', 'EBV')
#  ('All', 'ZSPEC') ('All', 'ZMAG') ('All', 'ZMAG_ERR') ('g', 'MODEL_MAG')
#  ('g', 'MODEL_MAGERR') ('r', 'MODEL_MAG') ('r', 'MODEL_MAGERR')
#  ('i', 'MODEL_MAG') ('i', 'MODEL_MAGERR') ('z', 'MODEL_MAG')
#  ('z', 'MODEL_MAGERR') ('All', 'flags') ('All', 'mask_frac')
#  ('All', 'psf_e1') ('All', 'psf_e2') ('All', 'psf_size')
#  ('All', 'mcal_psf_e1') ('All', 'mcal_psf_e2') ('All', 'mcal_psf_size')
#  ('All', 'e1') ('All', 'e1_1p') ('All', 'e1_1m') ('All', 'e1_2p')
#  ('All', 'e1_2m') ('All', 'e2') ('All', 'e2_1p') ('All', 'e2_1m')
#  ('All', 'e2_2p') ('All', 'e2_2m') ('All', 'size') ('All', 'size_1p')
# ...

# %%
shape
# Out:
# Band                All                                                       \
# Data       MEM_MATCH_ID         Z          RA        DEC         R         P
# ID
# 3007825807          620  0.619567  317.677388   0.374833  0.935984  0.376686
# 3007825827          620  0.619567  317.699737   0.375196  0.820374  0.640158
# 3007825954          620  0.619567  317.729812   0.377189  0.952016  0.248513
# 3007826482          620  0.619567  317.702711   0.385457  0.992318  0.293591
# 3007888251         3872  0.393719  318.395188   1.324740  0.764320  0.085390
# ...                 ...       ...         ...        ...       ...       ...
# 3159945451         6369  0.385452  307.568648 -49.601638  0.664473  0.033394
# 3159945721         6369  0.385452  307.459290 -49.611175  0.421528  0.816355
# 3159945947         6369  0.385452  307.574785 -49.615485  0.780249  0.158794
# 3159946033         6369  0.385452  307.528668 -49.615762  0.467721  0.836948
# ...

# %%
len(set(shape[('All','MEM_MATCH_ID')].to_numpy()))
# Out:
# 7001
