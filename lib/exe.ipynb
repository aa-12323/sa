# %%
import papermill as pm

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/phi_e_sat.ipynb',
   '/home/cz136/project/sa/lib/output/test.ipynb',
   parameters = dict(shape_cat="im3",z_range="high",vol="full")
)

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/mcal.ipynb',
   parameters = dict(shape_cat="mcal")
)
# Out:
# ...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/nbconvert/preprocessors/execute.py", line 348, in setup_preprocessor
#     yield nb, self.km, self.kc
#   File "/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/papermill/preprocess.py", line 23, in preprocess
#     nb, resources = self.papermill_process(nb_man, resources)
#   File "/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/papermill/preprocess.py", line 63, in papermill_process
#     nb.cells[index], resources = self.preprocess_cell(cell, resources, index)
#   File "/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/nbconvert/preprocessors/execute.py", line 438, in preprocess_cell
#     reply, outputs = self.run_cell(cell, cell_index, store_history)
# ...

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/mcal.ipynb',
   parameters = dict(shape_cat="im3")
)
