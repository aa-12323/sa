# %%
import papermill as pm

# %% [markdown]
# # Data

# %%
shape_list=["mcal","im3"]
vol_list=["all","vlim"]
z_list=["all_z","high_z","low_z"]

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/mcal_all.ipynb',
   parameters = dict(shape_cat="mcal",vol="all")
)
# Out:
# HBox(children=(IntProgress(value=0, description='Executing', max=71, style=ProgressStyle(description_width='in…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:07:58.105974',
#      'end_time': '2019-10-26T07:07:58.135460',
#      'duration': 0.029486,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_cat=""\nvol=""'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:07:58.160266',
#      'end_time': '2019-10-26T07:07:58.188584',
#      'duration': 0.028318,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\nshape_cat = "mcal"\nvol = "all"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:07:58.212271',
#      'end_time': '2019-10-26T07:08:00.087467',
#      'duration': 1.875196,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'from astropy.io import fits\nfrom astropy.table import Table\nimport pandas as pd\nimport fitsio as fio\nimport numpy as np\nimport ast\n\nimport astropy.cosmology\nfrom astropy.coordinates import SkyCoord  # High-level coordinates\nfrom astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames\nfrom astropy.coordinates import Angle, Latitude, Longitude  # Angles\nimport astropy.units as u\nfrom IPython.display import display, Math'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:08:00.112830',
#      'end_time': '2019-10-26T07:08:01.046688',
#      'duration': 0.933858,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '809723\n16966\n5621\n'}],
#    'source': 'if vol=="vlim":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl50.fit\')[1].data)\nelif vol=="all":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl02.fit\')[1].data)\nelse:\n    raise TypeError("Wrong vol")\ncluster_table.remove_columns([\'P_C\',\'C_LAMBDA\',\'C_LAMBDA_ERR\',\'Q_CEN\']) #unknown columns\n\nprint(len(member_table))\nprint(len(cluster_table))\nprint(len(member_table[\'ID\'])-len(np.unique(member_table[\'ID\'])))'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:08:01.072527',
#      'end_time': '2019-10-26T07:09:47.868594',
#      'duration': 106.796067,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Metacal loaded\n'}],
#    'source': 'if shape_cat=="mcal":\n    mcal = fio.FITS(\'/lsst/troxel/y1a1/mcal-y1a1-combined-riz-unblind-v4-matched.fits\',memmap=True,mode=\'r\')[1]\n    print ("Metacal loaded")\n    shape_id=mcal[\'coadd_objects_id\'][:] \nelif shape_cat=="im3":\n        mcal = fio.FITS(\'/lsst/troxel/y1a1/y1a1-im3shape_v5_unblind_v2_matched_v4.fits\',memmap=True,mode=\'r\')[1]\n        print ("Metacal loaded")\n        shape_id=mcal[\'coadd_objects_id\'][:] \nelse:\n    raise '},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:47.901050',
#      'end_time': '2019-10-26T07:09:47.934675',
#      'duration': 0.033625,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "problem_list =['MODEL_MAG', 'MODEL_MAGERR', 'MAG_LAMBDA_ERR', 'PZBINS',\n               'PZ', 'RA_CENT', 'DEC_CENT', 'ID_CENT', 'LAMBDA_CHISQ_CENT',\n               'ZLAMBDA_CENT', 'P_BCG', 'P_CEN', 'P_FG', 'P_SAT']"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:47.962930',
#      'end_time': '2019-10-26T07:09:48.000269',
#      'duration': 0.037339,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'band_col_list = []\npz_col_list = []\nalt_col_list =[]\nfor problem in problem_list:\n    if cluster_table[problem].shape[1]==4:\n        band_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==5:\n        alt_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==21:\n        pz_col_list.append(problem)\n    else:\n        print ("error")'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.029774',
#      'end_time': '2019-10-26T07:09:48.066161',
#      'duration': 0.036387,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "band_list=['g','r','i','z','Y']\npz_index_list=['pz'+str(i+1) for i in range(21)]\nalt_index_list=['Alt'+str(i+1) for i in range(5)]"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.096233',
#      'end_time': '2019-10-26T07:09:48.138011',
#      'duration': 0.041778,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list):\n        cluster_table[str(('Band',band_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(band_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.163057',
#      'end_time': '2019-10-26T07:09:48.240434',
#      'duration': 0.077377,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(pz_col_list):\n    for j in range(21):\n        cluster_table[str(('PZ',pz_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(pz_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.270426',
#      'end_time': '2019-10-26T07:09:48.365962',
#      'duration': 0.095536,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(alt_col_list):\n    for j in range(5):\n        cluster_table[str(('Alt',alt_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(alt_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.398643',
#      'end_time': '2019-10-26T07:09:48.518233',
#      'duration': 0.11959,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "all_col_list=list(cluster_table.columns[0:54])\nfor i,column in enumerate(all_col_list):\n    cluster_table[str(('All','All',column))]=cluster_table[column].data[:]\ncluster_table.remove_columns(all_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.549333',
#      'end_time': '2019-10-26T07:09:48.619930',
#      'duration': 0.070597,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list[0:2]):\n        member_table['('+band_list[j]+','+column+')']=member_table[column].data[:,j]\nmember_table.remove_columns(band_col_list[0:2]) "},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:48.650390',
#      'end_time': '2019-10-26T07:09:49.239564',
#      'duration': 0.589174,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'clusters=cluster_table.to_pandas()\nmember=member_table.to_pandas()\nrandom=random_table.to_pandas()\n# center_table=None\n# member_table=None'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.265542',
#      'end_time': '2019-10-26T07:09:49.300453',
#      'duration': 0.034911,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_cols = member.columns[0:22]\nshape_columns=pd.MultiIndex.from_product([['All'],list(mcal.get_colnames())],names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.324765',
#      'end_time': '2019-10-26T07:09:49.360652',
#      'duration': 0.035887,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "center_bins=[m+str(n) for m,n in zip(['cen_']*5,np.arange(5)+1)]\ncenter=pd.MultiIndex.from_product([['Center'],center_bins,member_cols])"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.386534',
#      'end_time': '2019-10-26T07:09:49.417105',
#      'duration': 0.030571,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR','MAG_LAMBDA_ERR']],\n                                     names=['band','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.441008',
#      'end_time': '2019-10-26T07:09:49.471411',
#      'duration': 0.030403,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# alt_bins=[m+str(n) for m,n in zip(['alt_']*5,np.arange(5)+1)]\n# alt_columns=pd.MultiIndex.from_product([alt_bins,\n#                                        alt_col_list.append(shape_names)],\n#                                      names=['alt_index','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.496162',
#      'end_time': '2019-10-26T07:09:49.530294',
#      'duration': 0.034132,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR',]],\n                                     names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.554259',
#      'end_time': '2019-10-26T07:09:49.588534',
#      'duration': 0.034275,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_index=pd.MultiIndex.from_tuples([('MEM_MATCH_ID','TYPE')],names=['ClusterID','Type'])"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.613324',
#      'end_time': '2019-10-26T07:09:49.649024',
#      'duration': 0.0357,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random_columns=pd.MultiIndex.from_product([['All'],['RA', 'DEC', 'Z', 'LAMBDA_IN', 'AVG_LAMBDAOUT', 'SIGMA_LAMBDAOUT', 'WEIGHT']],\n                                       names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.672515',
#      'end_time': '2019-10-26T07:09:49.702567',
#      'duration': 0.030052,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'random.columns=random_columns'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.727400',
#      'end_time': '2019-10-26T07:09:49.759253',
#      'duration': 0.031853,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_id=member['ID'].values"},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.782762',
#      'end_time': '2019-10-26T07:09:49.810247',
#      'duration': 0.027485,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# for id in member_id:\n#     mask = pd.Series(shape_id)==id'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.834942',
#      'end_time': '2019-10-26T07:09:49.866804',
#      'duration': 0.031862,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_id_series = pd.Series(shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.890498',
#      'end_time': '2019-10-26T07:09:49.920577',
#      'duration': 0.030079,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def sort2n(x,y):\n    """\n    Sorts and matches two arrays of object ids where x is unique and y is not (in DES this is coadd_objects_id).\n    Slower than sort2().\n    """\n    \n    xsort = np.argsort(x)\n    ysort = np.argsort(y)\n    i_yx = np.sort(y[np.in1d(y, x, assume_unique=False)])\n    i_x = xsort[x[xsort].searchsorted(i_yx)]\n    i_y = ysort[y[ysort].searchsorted(i_yx)]\n    \n    return i_x, i_y'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:09:49.945240',
#      'end_time': '2019-10-26T07:10:18.744612',
#      'duration': 28.799372,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 's2n_index=sort2n(member_id,shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:10:18.774520',
#      'end_time': '2019-10-26T07:11:13.023388',
#      'duration': 54.248868,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_half=pd.DataFrame(mcal.read(rows=[s2n_index[1]]).byteswap().newbyteorder())'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.057690',
#      'end_time': '2019-10-26T07:11:13.261647',
#      'duration': 0.203957,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'member_half=member.iloc[s2n_index[0]]'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.289992',
#      'end_time': '2019-10-26T07:11:13.329632',
#      'duration': 0.03964,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_half_index=pd.MultiIndex.from_tuples(list(zip(['All']*23,member_half.columns[0:23]))+list(member_band_columns),names=['Band','Data']) "},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.357228',
#      'end_time': '2019-10-26T07:11:13.389354',
#      'duration': 0.032126,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_half.columns=shape_columns\nmember_half.columns=member_half_index\nshape_half.set_index(('All','coadd_objects_id'),inplace=True)\nmember_half.set_index(('All','ID'),inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.414308',
#      'end_time': '2019-10-26T07:11:13.777116',
#      'duration': 0.362808,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shapes=pd.concat([member_half,shape_half],axis=1,verify_integrity=True)\nshapes.index.name="ID"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.803247',
#      'end_time': '2019-10-26T07:11:13.827440',
#      'duration': 0.024193,
#      'status': 'completed'}},
#    'source': '# im3 e correction'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.851455',
#      'end_time': '2019-10-26T07:11:13.882638',
#      'duration': 0.031183,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'if shape_cat == "im3":\n    shapes[(\'All\',\'e1_old\')]=shapes[(\'All\',\'e1\')]\n    shapes[(\'All\',\'e2_old\')]=shapes[(\'All\',\'e2\')]\n    shapes[(\'All\',\'e1\')]=shapes.apply(lambda x:x[(\'All\',\'e1\')]-x[(\'All\',\'c1\')],axis=1)\n    shapes[(\'All\',\'e2\')]=shapes.apply(lambda x:x[(\'All\',\'e2\')]-x[(\'All\',\'c2\')],axis=1)'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.907611',
#      'end_time': '2019-10-26T07:11:13.940512',
#      'duration': 0.032901,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_col_list=[ast.literal_eval(name) for i,name in enumerate(clusters.columns)]\ncluster_col=pd.MultiIndex.from_tuples(cluster_col_list, names=['Type','Kind','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:13.963670',
#      'end_time': '2019-10-26T07:11:13.992844',
#      'duration': 0.029174,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.columns=cluster_col\nclusters.set_index(('All', 'All', 'MEM_MATCH_ID'),inplace=True);"},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:14.017511',
#      'end_time': '2019-10-26T07:11:14.047651',
#      'duration': 0.03014,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_theta_for_obj(obj1,obj2):\n    ra1,dec1=(obj1[('All', 'RA')],obj1[('All', 'DEC')])\n    ra2,dec2=(obj2[('All', 'RA')],obj2[('All', 'DEC')])\n    \n    \n    \n    c1=SkyCoord(ra1*u.deg,dec1*u.deg)\n    c2=SkyCoord(ra2*u.deg,dec2*u.deg)\n    \n    \n    return(90-c1.position_angle(c2).degree)"},
#   {'cell_type': 'code',
#    'execution_count': 37,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:14.071813',
#      'end_time': '2019-10-26T07:11:14.100560',
#      'duration': 0.028747,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_rel_theta(member):\n    cluster=clusters.loc[member[('All','MEM_MATCH_ID')]]\n    center=shapes.loc[cluster[('Alt','Alt1','ID_CENT')]]\n    theta=get_theta_for_obj(center,member)\n    return(theta)"},
#   {'cell_type': 'code',
#    'execution_count': 38,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:14.125349',
#      'end_time': '2019-10-26T07:11:44.701775',
#      'duration': 30.576426,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Added PP column.\n'}],
#    'source': 'shapes[(\'All\',\'PP\')]=shapes.apply(lambda x:x[(\'All\',\'P\')]*x[(\'All\',\'PFREE\')],axis=1)\nprint ("Added PP column.")'},
#   {'cell_type': 'code',
#    'execution_count': 39,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:44.740358',
#      'end_time': '2019-10-26T07:11:46.085260',
#      'duration': 1.344902,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes=shapes[shapes[('All', 'flags_select')]==0]\nshapes=shapes[shapes[('All','PP')]>=0.55]"},
#   {'cell_type': 'code',
#    'execution_count': 40,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:46.112110',
#      'end_time': '2019-10-26T07:11:46.513388',
#      'duration': 0.401278,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: \nPassing list-likes to .loc or [] with any missing label will raise\nKeyError in the future, you can use .reindex() as an alternative.\n\nSee the documentation here:\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike\n  after removing the cwd from sys.path.\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'The number of clusters with no center shape data 4483\nNumber of galaxies before masking: 282735\nNumber of galaxies after masking: 282735\nThe number of clusters with no center shape data 1\nNumber of galaxies before masking: 203080\nNumber of galaxies after masking: 203080\n'}],
#    'source': '# Drop clusters with no center\ndef drop_poor_centers():\n    center_id=clusters[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n    p=shapes.loc[center_id][(\'All\',\'P\')].to_numpy()\n    missing_mem_match_id=clusters[np.isnan(p)].index\n    clusters.drop(missing_mem_match_id,inplace=True)\n#     np.save("/home/cz136/project/sa/data/missing_centers.npy",center_id[np.isnan(p)].to_numpy())\n    print("The number of clusters with no center shape data {}".format(np.sum(np.isnan(p))))\ndrop_poor_centers()\n\n# Drop members with no cluster\ndef drop_poor_members():\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    return(valid_members)\n    \nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]\n\ndrop_poor_centers()\nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]'},
#   {'cell_type': 'code',
#    'execution_count': 41,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:11:46.542164',
#      'end_time': '2019-10-26T07:18:35.619637',
#      'duration': 409.077473,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:get_rel_theta(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 42,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:18:35.647334',
#      'end_time': '2019-10-26T07:18:59.095572',
#      'duration': 23.448238,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:360-x[('All','Theta_cen')] if x[('All','Theta_cen')]>=180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_cen')]=shapes.apply(lambda x:360+x[('All','Theta_cen')] if x[('All','Theta_cen')]<=-180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_sat')]=shapes.apply(lambda x:-(180-x[('All','Theta_cen')]) if x[('All','Theta_cen')]>=0 else (180+x[('All','Theta_cen')]),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 43,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:18:59.124926',
#      'end_time': '2019-10-26T07:18:59.156871',
#      'duration': 0.031945,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'H0=100 #km s-1 Mpc-1\nOm0=0.3\nOde0=0.7\nlcdm=astropy.cosmology.FlatLambdaCDM(H0, Om0)'},
#   {'cell_type': 'code',
#    'execution_count': 44,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:18:59.181913',
#      'end_time': '2019-10-26T07:27:11.212391',
#      'duration': 492.030478,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','angR')]=shapes.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)\nrandom[('All','angR')]=random.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:27:11.243417',
#      'end_time': '2019-10-26T07:27:11.270014',
#      'duration': 0.026597,
#      'status': 'completed'}},
#    'source': '# Add $\\phi$'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:27:11.295955',
#      'end_time': '2019-10-26T07:27:11.330766',
#      'duration': 0.034811,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_pa_for_member(obj):\n    e1=obj['All']['e1']\n    e2=obj['All']['e2']\n    \n    α =0.5*np.arctan2(-e2,-e1)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:27:11.359127',
#      'end_time': '2019-10-26T07:27:11.391746',
#      'duration': 0.032619,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'error_list_phi=[]\nerror_list_e=[]\n\ndef get_phi_for_member(member):\n    \n    """Input: cluster series\n        Output: an array of position angle weighted by PP\n        Record KeyError in an array (usually caused by uncomplete shape catalog).\n    """\n    \n    try:\n        cluster_id=member[(\'All\',\'MEM_MATCH_ID\')]\n        cluster=clusters.loc[cluster_id]\n        center_id=cluster[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n        center = shapes.loc[center_id]\n        \n        pa=get_pa_for_member(member)\n        theta= get_theta_for_obj(member,center)\n        phi=(pa-theta)\n    #     print(center.index)\n        return(phi)    \n    except KeyError as e:\n        error_list_phi.append(e)\n        print(e)\n        return(np.nan)'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:27:11.416369',
#      'end_time': '2019-10-26T07:36:06.083113',
#      'duration': 534.666744,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=shapes.apply(lambda x:get_phi_for_member(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:36:06.112967',
#      'end_time': '2019-10-26T07:36:06.144076',
#      'duration': 0.031109,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def process_phi(phi_1d):\n\n    phi_1d=np.where(phi_1d<=0,-phi_1d,phi_1d)\n    phi_1d=np.where(phi_1d>=180,phi_1d-180,phi_1d)\n    phi_1d=np.where(phi_1d>=90,180-phi_1d,phi_1d)\n\n    \n    return(phi_1d)'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:36:06.168456',
#      'end_time': '2019-10-26T07:36:06.213637',
#      'duration': 0.045181,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=process_phi(shapes[('All','phi')])"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:36:06.242109',
#      'end_time': '2019-10-26T07:36:06.266682',
#      'duration': 0.024573,
#      'status': 'completed'}},
#    'source': '# Add e'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:36:06.291592',
#      'end_time': '2019-10-26T07:36:06.331060',
#      'duration': 0.039468,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_e(sat):\n    cluster_id=sat[('All','MEM_MATCH_ID')]\n    cluster=clusters.loc[cluster_id]\n    center_id=cluster[('Alt', 'Alt1', 'ID_CENT')]\n    cen = shapes.loc[center_id]\n    \n    e=np.sqrt(sat[('All','e1')]**2+sat[('All','e2')]**2)\n    delta=get_theta_for_obj(cen,sat)\n    alpha=get_pa_for_member(sat)\n    ep,ex=(e*np.cos(2*(delta-alpha)),e*np.sin(2*(delta-alpha)))\n    return(ep,ex)"},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:36:06.361136',
#      'end_time': '2019-10-26T07:54:14.407800',
#      'duration': 1088.046664,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','ep')]=shapes.apply(lambda x:get_e(x)[0],axis=1)\nshapes[('All','ex')]=shapes.apply(lambda x:get_e(x)[1],axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:54:14.437693',
#      'end_time': '2019-10-26T07:54:14.463318',
#      'duration': 0.025625,
#      'status': 'completed'}},
#    'source': '# Calculate cluster elipticity'},
#   {'cell_type': 'code',
#    'execution_count': 52,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:54:14.488693',
#      'end_time': '2019-10-26T07:54:14.527491',
#      'duration': 0.038798,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<IPython.core.display.Math object>',
#       'text/latex': '$\\displaystyle M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$'}}],
#    'source': 'display(Math(r"$M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$"))'},
#   {'cell_type': 'code',
#    'execution_count': 53,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:54:14.554409',
#      'end_time': '2019-10-26T07:54:14.594782',
#      'duration': 0.040373,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_Q_U(cluster):\n    \n    mem_match_id=cluster.name\n    members=shapes[shapes['All','MEM_MATCH_ID']==mem_match_id]\n    \n    members=members[members[('All','PP')]>=0.2]\n    \n    def get_M_for_cluster():\n        p = members[('All','PP')]\n        r = members[('All','R')]\n        pa = members[('All','Theta_cen')]\n        x = r * np.cos(pa)\n        y = r * np.sin(pa)\n        \n        def mom_2(p,x,y,r):\n            return(np.sum(p*x*y/r**2)/np.sum(p))\n        \n        Mxx=mom_2(p,x,x,r)\n        Mxy=mom_2(p,x,y,r)\n        Myy=mom_2(p,y,y,r)\n        return(Mxx,Mxy,Myy)\n\n    Mxx,Mxy,Myy=get_M_for_cluster()\n    Q,U=Mxx-Myy,2*Mxy\n    \n    return (Q,U)\n\n\ndef get_pa_from_Q_U(Q,U):\n    α =0.5*np.arctan2(U,Q)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 54,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:54:14.618700',
#      'end_time': '2019-10-26T07:55:48.930705',
#      'duration': 94.312005,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters[('All','All','Q')]=clusters.apply(lambda x:get_Q_U(x)[0],axis=1)\nclusters[('All','All','U')]=clusters.apply(lambda x:get_Q_U(x)[1],axis=1)\nclusters[('All','All','Beta')]=clusters.apply(lambda x:get_pa_from_Q_U(x[('All','All','Q')],x[('All','All','U')]),axis=1)\nclusters[('All','All','Ce')]=clusters.apply(lambda x:np.sqrt(x[('All','All','U')]**2+x[('All','All','U')]**2),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 55,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:55:48.963353',
#      'end_time': '2019-10-26T07:55:49.002963',
#      'duration': 0.03961,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_normLR(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    angR=shape[('All','angR')]\n    normR=angR/LR\n    return(normR)"},
#   {'cell_type': 'code',
#    'execution_count': 56,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:55:49.032766',
#      'end_time': '2019-10-26T07:56:49.832555',
#      'duration': 60.799789,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','normLR')]=shapes.apply(lambda x:get_normLR(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 57,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:56:49.860490',
#      'end_time': '2019-10-26T07:56:49.899212',
#      'duration': 0.038722,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def add_r_lambda(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    return(LR)"},
#   {'cell_type': 'code',
#    'execution_count': 58,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:56:49.928335',
#      'end_time': '2019-10-26T07:57:47.377876',
#      'duration': 57.449541,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','R_LAMBDA')]=shapes.apply(lambda x:add_r_lambda(x),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:47.413903',
#      'end_time': '2019-10-26T07:57:47.444509',
#      'duration': 0.030606,
#      'status': 'completed'}},
#    'source': '# Save'},
#   {'cell_type': 'code',
#    'execution_count': 59,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:47.469894',
#      'end_time': '2019-10-26T07:57:47.564391',
#      'duration': 0.094497,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 60,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:47.597331',
#      'end_time': '2019-10-26T07:57:48.657866',
#      'duration': 1.060535,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 61,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:48.711310',
#      'end_time': '2019-10-26T07:57:49.767809',
#      'duration': 1.056499,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random.to_pickle('/home/cz136/project/sa/data/{}/{}/random.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:49.823058',
#      'end_time': '2019-10-26T07:57:49.853877',
#      'duration': 0.030819,
#      'status': 'completed'}},
#    'source': '## z masking'},
#   {'cell_type': 'code',
#    'execution_count': 62,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:49.879673',
#      'end_time': '2019-10-26T07:57:49.911232',
#      'duration': 0.031559,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def drop_shapes_wo_cluster(clusters,shapes):\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    shapes=shapes[valid_members]\n    return(shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 63,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:49.939953',
#      'end_time': '2019-10-26T07:57:49.978470',
#      'duration': 0.038517,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z=clusters[clusters['All','All','Z_LAMBDA']>=0.35]\nlow_z=clusters[(clusters['All','All','Z_LAMBDA']<=0.35) & (clusters['All','All','Z_LAMBDA']>=0.1)]"},
#   {'cell_type': 'code',
#    'execution_count': 64,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:50.006574',
#      'end_time': '2019-10-26T07:57:50.215060',
#      'duration': 0.208486,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Number of galaxies before masking: 203070\nNumber of galaxies before masking: 203070\n'}],
#    'source': 'high_z_shapes=drop_shapes_wo_cluster(high_z,shapes)\nlow_z_shapes=drop_shapes_wo_cluster(low_z,shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 65,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:50.246141',
#      'end_time': '2019-10-26T07:57:51.285024',
#      'duration': 1.038883,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_high_z.pkl'.format(shape_cat,vol))\nlow_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_low_z.pkl'.format(shape_cat,vol))\nhigh_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_high_z.pkl'.format(shape_cat,vol))\nlow_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_low_z.pkl'.format(shape_cat,vol))"}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'shape_cat': 'mcal', 'vol': 'all'},
#    'environment_variables': {},
#    'version': '1.2.0',
#    'input_path': '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
#    'output_path': '/home/cz136/project/sa/lib/output/data/mcal_all.ipynb',
#    'start_time': '2019-10-26T07:07:56.539465',
#    'end_time': '2019-10-26T07:57:52.019097',
#    'duration': 2995.479632,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/mcal_vlim.ipynb',
   parameters = dict(shape_cat="mcal",vol="vlim")
)
# Out:
# HBox(children=(IntProgress(value=0, description='Executing', max=71, style=ProgressStyle(description_width='in…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:53.309027',
#      'end_time': '2019-10-26T07:57:53.347778',
#      'duration': 0.038751,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_cat=""\nvol=""'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:53.373747',
#      'end_time': '2019-10-26T07:57:53.402368',
#      'duration': 0.028621,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\nshape_cat = "mcal"\nvol = "vlim"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:53.427726',
#      'end_time': '2019-10-26T07:57:54.994574',
#      'duration': 1.566848,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'from astropy.io import fits\nfrom astropy.table import Table\nimport pandas as pd\nimport fitsio as fio\nimport numpy as np\nimport ast\n\nimport astropy.cosmology\nfrom astropy.coordinates import SkyCoord  # High-level coordinates\nfrom astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames\nfrom astropy.coordinates import Angle, Latitude, Longitude  # Angles\nimport astropy.units as u\nfrom IPython.display import display, Math'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:55.020991',
#      'end_time': '2019-10-26T07:57:55.684022',
#      'duration': 0.663031,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '399002\n7066\n1427\n'}],
#    'source': 'if vol=="vlim":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl50.fit\')[1].data)\nelif vol=="all":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl02.fit\')[1].data)\nelse:\n    raise TypeError("Wrong vol")\ncluster_table.remove_columns([\'P_C\',\'C_LAMBDA\',\'C_LAMBDA_ERR\',\'Q_CEN\']) #unknown columns\n\nprint(len(member_table))\nprint(len(cluster_table))\nprint(len(member_table[\'ID\'])-len(np.unique(member_table[\'ID\'])))'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:57:55.715336',
#      'end_time': '2019-10-26T07:59:47.259692',
#      'duration': 111.544356,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Metacal loaded\n'}],
#    'source': 'if shape_cat=="mcal":\n    mcal = fio.FITS(\'/lsst/troxel/y1a1/mcal-y1a1-combined-riz-unblind-v4-matched.fits\',memmap=True,mode=\'r\')[1]\n    print ("Metacal loaded")\n    shape_id=mcal[\'coadd_objects_id\'][:] \nelif shape_cat=="im3":\n        mcal = fio.FITS(\'/lsst/troxel/y1a1/y1a1-im3shape_v5_unblind_v2_matched_v4.fits\',memmap=True,mode=\'r\')[1]\n        print ("Metacal loaded")\n        shape_id=mcal[\'coadd_objects_id\'][:] \nelse:\n    raise '},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.292363',
#      'end_time': '2019-10-26T07:59:47.330228',
#      'duration': 0.037865,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "problem_list =['MODEL_MAG', 'MODEL_MAGERR', 'MAG_LAMBDA_ERR', 'PZBINS',\n               'PZ', 'RA_CENT', 'DEC_CENT', 'ID_CENT', 'LAMBDA_CHISQ_CENT',\n               'ZLAMBDA_CENT', 'P_BCG', 'P_CEN', 'P_FG', 'P_SAT']"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.356880',
#      'end_time': '2019-10-26T07:59:47.388398',
#      'duration': 0.031518,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'band_col_list = []\npz_col_list = []\nalt_col_list =[]\nfor problem in problem_list:\n    if cluster_table[problem].shape[1]==4:\n        band_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==5:\n        alt_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==21:\n        pz_col_list.append(problem)\n    else:\n        print ("error")'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.413929',
#      'end_time': '2019-10-26T07:59:47.445805',
#      'duration': 0.031876,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "band_list=['g','r','i','z','Y']\npz_index_list=['pz'+str(i+1) for i in range(21)]\nalt_index_list=['Alt'+str(i+1) for i in range(5)]"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.470835',
#      'end_time': '2019-10-26T07:59:47.510071',
#      'duration': 0.039236,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list):\n        cluster_table[str(('Band',band_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(band_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.539143',
#      'end_time': '2019-10-26T07:59:47.608480',
#      'duration': 0.069337,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(pz_col_list):\n    for j in range(21):\n        cluster_table[str(('PZ',pz_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(pz_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.636560',
#      'end_time': '2019-10-26T07:59:47.721627',
#      'duration': 0.085067,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(alt_col_list):\n    for j in range(5):\n        cluster_table[str(('Alt',alt_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(alt_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.748671',
#      'end_time': '2019-10-26T07:59:47.861225',
#      'duration': 0.112554,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "all_col_list=list(cluster_table.columns[0:54])\nfor i,column in enumerate(all_col_list):\n    cluster_table[str(('All','All',column))]=cluster_table[column].data[:]\ncluster_table.remove_columns(all_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.894639',
#      'end_time': '2019-10-26T07:59:47.942449',
#      'duration': 0.04781,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list[0:2]):\n        member_table['('+band_list[j]+','+column+')']=member_table[column].data[:,j]\nmember_table.remove_columns(band_col_list[0:2]) "},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:47.966873',
#      'end_time': '2019-10-26T07:59:48.465346',
#      'duration': 0.498473,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'clusters=cluster_table.to_pandas()\nmember=member_table.to_pandas()\nrandom=random_table.to_pandas()\n# center_table=None\n# member_table=None'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.491259',
#      'end_time': '2019-10-26T07:59:48.529876',
#      'duration': 0.038617,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_cols = member.columns[0:22]\nshape_columns=pd.MultiIndex.from_product([['All'],list(mcal.get_colnames())],names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.554013',
#      'end_time': '2019-10-26T07:59:48.586208',
#      'duration': 0.032195,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "center_bins=[m+str(n) for m,n in zip(['cen_']*5,np.arange(5)+1)]\ncenter=pd.MultiIndex.from_product([['Center'],center_bins,member_cols])"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.613732',
#      'end_time': '2019-10-26T07:59:48.645459',
#      'duration': 0.031727,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR','MAG_LAMBDA_ERR']],\n                                     names=['band','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.669726',
#      'end_time': '2019-10-26T07:59:48.701790',
#      'duration': 0.032064,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# alt_bins=[m+str(n) for m,n in zip(['alt_']*5,np.arange(5)+1)]\n# alt_columns=pd.MultiIndex.from_product([alt_bins,\n#                                        alt_col_list.append(shape_names)],\n#                                      names=['alt_index','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.732903',
#      'end_time': '2019-10-26T07:59:48.770769',
#      'duration': 0.037866,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR',]],\n                                     names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.801451',
#      'end_time': '2019-10-26T07:59:48.835915',
#      'duration': 0.034464,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_index=pd.MultiIndex.from_tuples([('MEM_MATCH_ID','TYPE')],names=['ClusterID','Type'])"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.860757',
#      'end_time': '2019-10-26T07:59:48.898637',
#      'duration': 0.03788,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random_columns=pd.MultiIndex.from_product([['All'],['RA', 'DEC', 'Z', 'LAMBDA_IN', 'AVG_LAMBDAOUT', 'SIGMA_LAMBDAOUT', 'WEIGHT']],\n                                       names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.925673',
#      'end_time': '2019-10-26T07:59:48.958590',
#      'duration': 0.032917,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'random.columns=random_columns'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:48.983612',
#      'end_time': '2019-10-26T07:59:49.017588',
#      'duration': 0.033976,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_id=member['ID'].values"},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:49.043418',
#      'end_time': '2019-10-26T07:59:49.075824',
#      'duration': 0.032406,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# for id in member_id:\n#     mask = pd.Series(shape_id)==id'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:49.104403',
#      'end_time': '2019-10-26T07:59:49.137904',
#      'duration': 0.033501,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_id_series = pd.Series(shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:49.162582',
#      'end_time': '2019-10-26T07:59:49.201399',
#      'duration': 0.038817,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def sort2n(x,y):\n    """\n    Sorts and matches two arrays of object ids where x is unique and y is not (in DES this is coadd_objects_id).\n    Slower than sort2().\n    """\n    \n    xsort = np.argsort(x)\n    ysort = np.argsort(y)\n    i_yx = np.sort(y[np.in1d(y, x, assume_unique=False)])\n    i_x = xsort[x[xsort].searchsorted(i_yx)]\n    i_y = ysort[y[ysort].searchsorted(i_yx)]\n    \n    return i_x, i_y'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T07:59:49.233958',
#      'end_time': '2019-10-26T08:00:17.765407',
#      'duration': 28.531449,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 's2n_index=sort2n(member_id,shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:17.798140',
#      'end_time': '2019-10-26T08:00:20.957234',
#      'duration': 3.159094,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_half=pd.DataFrame(mcal.read(rows=[s2n_index[1]]).byteswap().newbyteorder())'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:20.984353',
#      'end_time': '2019-10-26T08:00:21.080069',
#      'duration': 0.095716,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'member_half=member.iloc[s2n_index[0]]'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.110102',
#      'end_time': '2019-10-26T08:00:21.149855',
#      'duration': 0.039753,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_half_index=pd.MultiIndex.from_tuples(list(zip(['All']*23,member_half.columns[0:23]))+list(member_band_columns),names=['Band','Data']) "},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.176139',
#      'end_time': '2019-10-26T08:00:21.212598',
#      'duration': 0.036459,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_half.columns=shape_columns\nmember_half.columns=member_half_index\nshape_half.set_index(('All','coadd_objects_id'),inplace=True)\nmember_half.set_index(('All','ID'),inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.237490',
#      'end_time': '2019-10-26T08:00:21.377198',
#      'duration': 0.139708,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shapes=pd.concat([member_half,shape_half],axis=1,verify_integrity=True)\nshapes.index.name="ID"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.408287',
#      'end_time': '2019-10-26T08:00:21.432277',
#      'duration': 0.02399,
#      'status': 'completed'}},
#    'source': '# im3 e correction'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.456002',
#      'end_time': '2019-10-26T08:00:21.487070',
#      'duration': 0.031068,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'if shape_cat == "im3":\n    shapes[(\'All\',\'e1_old\')]=shapes[(\'All\',\'e1\')]\n    shapes[(\'All\',\'e2_old\')]=shapes[(\'All\',\'e2\')]\n    shapes[(\'All\',\'e1\')]=shapes.apply(lambda x:x[(\'All\',\'e1\')]-x[(\'All\',\'c1\')],axis=1)\n    shapes[(\'All\',\'e2\')]=shapes.apply(lambda x:x[(\'All\',\'e2\')]-x[(\'All\',\'c2\')],axis=1)'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.516040',
#      'end_time': '2019-10-26T08:00:21.548920',
#      'duration': 0.03288,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_col_list=[ast.literal_eval(name) for i,name in enumerate(clusters.columns)]\ncluster_col=pd.MultiIndex.from_tuples(cluster_col_list, names=['Type','Kind','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.575667',
#      'end_time': '2019-10-26T08:00:21.611139',
#      'duration': 0.035472,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.columns=cluster_col\nclusters.set_index(('All', 'All', 'MEM_MATCH_ID'),inplace=True);"},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.638401',
#      'end_time': '2019-10-26T08:00:21.676624',
#      'duration': 0.038223,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_theta_for_obj(obj1,obj2):\n    ra1,dec1=(obj1[('All', 'RA')],obj1[('All', 'DEC')])\n    ra2,dec2=(obj2[('All', 'RA')],obj2[('All', 'DEC')])\n    \n    \n    \n    c1=SkyCoord(ra1*u.deg,dec1*u.deg)\n    c2=SkyCoord(ra2*u.deg,dec2*u.deg)\n    \n    \n    return(90-c1.position_angle(c2).degree)"},
#   {'cell_type': 'code',
#    'execution_count': 37,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.706747',
#      'end_time': '2019-10-26T08:00:21.737969',
#      'duration': 0.031222,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_rel_theta(member):\n    cluster=clusters.loc[member[('All','MEM_MATCH_ID')]]\n    center=shapes.loc[cluster[('Alt','Alt1','ID_CENT')]]\n    theta=get_theta_for_obj(center,member)\n    return(theta)"},
#   {'cell_type': 'code',
#    'execution_count': 38,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:21.765835',
#      'end_time': '2019-10-26T08:00:37.866506',
#      'duration': 16.100671,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Added PP column.\n'}],
#    'source': 'shapes[(\'All\',\'PP\')]=shapes.apply(lambda x:x[(\'All\',\'P\')]*x[(\'All\',\'PFREE\')],axis=1)\nprint ("Added PP column.")'},
#   {'cell_type': 'code',
#    'execution_count': 39,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:37.895123',
#      'end_time': '2019-10-26T08:00:38.382669',
#      'duration': 0.487546,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes=shapes[shapes[('All', 'flags_select')]==0]\nshapes=shapes[shapes[('All','PP')]>=0.55]"},
#   {'cell_type': 'code',
#    'execution_count': 40,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:38.409360',
#      'end_time': '2019-10-26T08:00:38.601271',
#      'duration': 0.191911,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'The number of clusters with no center shape data 2744\nNumber of galaxies before masking: 170325\nNumber of galaxies after masking: 170325\nThe number of clusters with no center shape data 0\nNumber of galaxies before masking: 104848\nNumber of galaxies after masking: 104848\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: \nPassing list-likes to .loc or [] with any missing label will raise\nKeyError in the future, you can use .reindex() as an alternative.\n\nSee the documentation here:\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike\n  after removing the cwd from sys.path.\n'}],
#    'source': '# Drop clusters with no center\ndef drop_poor_centers():\n    center_id=clusters[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n    p=shapes.loc[center_id][(\'All\',\'P\')].to_numpy()\n    missing_mem_match_id=clusters[np.isnan(p)].index\n    clusters.drop(missing_mem_match_id,inplace=True)\n#     np.save("/home/cz136/project/sa/data/missing_centers.npy",center_id[np.isnan(p)].to_numpy())\n    print("The number of clusters with no center shape data {}".format(np.sum(np.isnan(p))))\ndrop_poor_centers()\n\n# Drop members with no cluster\ndef drop_poor_members():\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    return(valid_members)\n    \nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]\n\ndrop_poor_centers()\nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]'},
#   {'cell_type': 'code',
#    'execution_count': 41,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:00:38.631956',
#      'end_time': '2019-10-26T08:04:10.107924',
#      'duration': 211.475968,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:get_rel_theta(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 42,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:04:10.144839',
#      'end_time': '2019-10-26T08:04:21.842734',
#      'duration': 11.697895,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:360-x[('All','Theta_cen')] if x[('All','Theta_cen')]>=180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_cen')]=shapes.apply(lambda x:360+x[('All','Theta_cen')] if x[('All','Theta_cen')]<=-180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_sat')]=shapes.apply(lambda x:-(180-x[('All','Theta_cen')]) if x[('All','Theta_cen')]>=0 else (180+x[('All','Theta_cen')]),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 43,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:04:21.873522',
#      'end_time': '2019-10-26T08:04:21.912138',
#      'duration': 0.038616,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'H0=100 #km s-1 Mpc-1\nOm0=0.3\nOde0=0.7\nlcdm=astropy.cosmology.FlatLambdaCDM(H0, Om0)'},
#   {'cell_type': 'code',
#    'execution_count': 44,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:04:21.941193',
#      'end_time': '2019-10-26T08:11:16.553789',
#      'duration': 414.612596,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','angR')]=shapes.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)\nrandom[('All','angR')]=random.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:11:16.583495',
#      'end_time': '2019-10-26T08:11:16.608845',
#      'duration': 0.02535,
#      'status': 'completed'}},
#    'source': '# Add $\\phi$'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:11:16.633635',
#      'end_time': '2019-10-26T08:11:16.671794',
#      'duration': 0.038159,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_pa_for_member(obj):\n    e1=obj['All']['e1']\n    e2=obj['All']['e2']\n    \n    α =0.5*np.arctan2(-e2,-e1)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:11:16.701692',
#      'end_time': '2019-10-26T08:11:16.740683',
#      'duration': 0.038991,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'error_list_phi=[]\nerror_list_e=[]\n\ndef get_phi_for_member(member):\n    \n    """Input: cluster series\n        Output: an array of position angle weighted by PP\n        Record KeyError in an array (usually caused by uncomplete shape catalog).\n    """\n    \n    try:\n        cluster_id=member[(\'All\',\'MEM_MATCH_ID\')]\n        cluster=clusters.loc[cluster_id]\n        center_id=cluster[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n        center = shapes.loc[center_id]\n        \n        pa=get_pa_for_member(member)\n        theta= get_theta_for_obj(member,center)\n        phi=(pa-theta)\n    #     print(center.index)\n        return(phi)    \n    except KeyError as e:\n        error_list_phi.append(e)\n        print(e)\n        return(np.nan)'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:11:16.765673',
#      'end_time': '2019-10-26T08:16:05.688563',
#      'duration': 288.92289,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=shapes.apply(lambda x:get_phi_for_member(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:16:05.714883',
#      'end_time': '2019-10-26T08:16:05.751084',
#      'duration': 0.036201,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def process_phi(phi_1d):\n\n    phi_1d=np.where(phi_1d<=0,-phi_1d,phi_1d)\n    phi_1d=np.where(phi_1d>=180,phi_1d-180,phi_1d)\n    phi_1d=np.where(phi_1d>=90,180-phi_1d,phi_1d)\n\n    \n    return(phi_1d)'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:16:05.775801',
#      'end_time': '2019-10-26T08:16:05.817178',
#      'duration': 0.041377,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=process_phi(shapes[('All','phi')])"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:16:05.845770',
#      'end_time': '2019-10-26T08:16:05.870740',
#      'duration': 0.02497,
#      'status': 'completed'}},
#    'source': '# Add e'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:16:05.895598',
#      'end_time': '2019-10-26T08:16:05.927679',
#      'duration': 0.032081,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_e(sat):\n    cluster_id=sat[('All','MEM_MATCH_ID')]\n    cluster=clusters.loc[cluster_id]\n    center_id=cluster[('Alt', 'Alt1', 'ID_CENT')]\n    cen = shapes.loc[center_id]\n    \n    e=np.sqrt(sat[('All','e1')]**2+sat[('All','e2')]**2)\n    delta=get_theta_for_obj(cen,sat)\n    alpha=get_pa_for_member(sat)\n    ep,ex=(e*np.cos(2*(delta-alpha)),e*np.sin(2*(delta-alpha)))\n    return(ep,ex)"},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:16:05.952889',
#      'end_time': '2019-10-26T08:25:32.648285',
#      'duration': 566.695396,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','ep')]=shapes.apply(lambda x:get_e(x)[0],axis=1)\nshapes[('All','ex')]=shapes.apply(lambda x:get_e(x)[1],axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:25:32.682996',
#      'end_time': '2019-10-26T08:25:32.708196',
#      'duration': 0.0252,
#      'status': 'completed'}},
#    'source': '# Calculate cluster elipticity'},
#   {'cell_type': 'code',
#    'execution_count': 52,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:25:32.732992',
#      'end_time': '2019-10-26T08:25:32.773705',
#      'duration': 0.040713,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<IPython.core.display.Math object>',
#       'text/latex': '$\\displaystyle M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$'}}],
#    'source': 'display(Math(r"$M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$"))'},
#   {'cell_type': 'code',
#    'execution_count': 53,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:25:32.799932',
#      'end_time': '2019-10-26T08:25:32.843780',
#      'duration': 0.043848,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_Q_U(cluster):\n    \n    mem_match_id=cluster.name\n    members=shapes[shapes['All','MEM_MATCH_ID']==mem_match_id]\n    \n    members=members[members[('All','PP')]>=0.2]\n    \n    def get_M_for_cluster():\n        p = members[('All','PP')]\n        r = members[('All','R')]\n        pa = members[('All','Theta_cen')]\n        x = r * np.cos(pa)\n        y = r * np.sin(pa)\n        \n        def mom_2(p,x,y,r):\n            return(np.sum(p*x*y/r**2)/np.sum(p))\n        \n        Mxx=mom_2(p,x,x,r)\n        Mxy=mom_2(p,x,y,r)\n        Myy=mom_2(p,y,y,r)\n        return(Mxx,Mxy,Myy)\n\n    Mxx,Mxy,Myy=get_M_for_cluster()\n    Q,U=Mxx-Myy,2*Mxy\n    \n    return (Q,U)\n\n\ndef get_pa_from_Q_U(Q,U):\n    α =0.5*np.arctan2(U,Q)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 54,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:25:32.868768',
#      'end_time': '2019-10-26T08:26:05.611384',
#      'duration': 32.742616,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters[('All','All','Q')]=clusters.apply(lambda x:get_Q_U(x)[0],axis=1)\nclusters[('All','All','U')]=clusters.apply(lambda x:get_Q_U(x)[1],axis=1)\nclusters[('All','All','Beta')]=clusters.apply(lambda x:get_pa_from_Q_U(x[('All','All','Q')],x[('All','All','U')]),axis=1)\nclusters[('All','All','Ce')]=clusters.apply(lambda x:np.sqrt(x[('All','All','U')]**2+x[('All','All','U')]**2),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 55,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:26:05.644170',
#      'end_time': '2019-10-26T08:26:05.679606',
#      'duration': 0.035436,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_normLR(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    angR=shape[('All','angR')]\n    normR=angR/LR\n    return(normR)"},
#   {'cell_type': 'code',
#    'execution_count': 56,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:26:05.707146',
#      'end_time': '2019-10-26T08:26:38.351161',
#      'duration': 32.644015,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','normLR')]=shapes.apply(lambda x:get_normLR(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 57,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:26:38.377723',
#      'end_time': '2019-10-26T08:26:38.408386',
#      'duration': 0.030663,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def add_r_lambda(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    return(LR)"},
#   {'cell_type': 'code',
#    'execution_count': 58,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:26:38.432790',
#      'end_time': '2019-10-26T08:27:09.299236',
#      'duration': 30.866446,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','R_LAMBDA')]=shapes.apply(lambda x:add_r_lambda(x),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:09.326244',
#      'end_time': '2019-10-26T08:27:09.351417',
#      'duration': 0.025173,
#      'status': 'completed'}},
#    'source': '# Save'},
#   {'cell_type': 'code',
#    'execution_count': 59,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:09.376504',
#      'end_time': '2019-10-26T08:27:09.476681',
#      'duration': 0.100177,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 60,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:09.511652',
#      'end_time': '2019-10-26T08:27:10.151238',
#      'duration': 0.639586,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 61,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:10.189489',
#      'end_time': '2019-10-26T08:27:11.174959',
#      'duration': 0.98547,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random.to_pickle('/home/cz136/project/sa/data/{}/{}/random.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:11.221953',
#      'end_time': '2019-10-26T08:27:11.250036',
#      'duration': 0.028083,
#      'status': 'completed'}},
#    'source': '## z masking'},
#   {'cell_type': 'code',
#    'execution_count': 62,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:11.275030',
#      'end_time': '2019-10-26T08:27:11.305570',
#      'duration': 0.03054,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def drop_shapes_wo_cluster(clusters,shapes):\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    shapes=shapes[valid_members]\n    return(shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 63,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:11.331074',
#      'end_time': '2019-10-26T08:27:11.367090',
#      'duration': 0.036016,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z=clusters[clusters['All','All','Z_LAMBDA']>=0.35]\nlow_z=clusters[(clusters['All','All','Z_LAMBDA']<=0.35) & (clusters['All','All','Z_LAMBDA']>=0.1)]"},
#   {'cell_type': 'code',
#    'execution_count': 64,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:11.391683',
#      'end_time': '2019-10-26T08:27:11.531395',
#      'duration': 0.139712,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Number of galaxies before masking: 104848\nNumber of galaxies before masking: 104848\n'}],
#    'source': 'high_z_shapes=drop_shapes_wo_cluster(high_z,shapes)\nlow_z_shapes=drop_shapes_wo_cluster(low_z,shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 65,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:11.558478',
#      'end_time': '2019-10-26T08:27:12.285758',
#      'duration': 0.72728,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_high_z.pkl'.format(shape_cat,vol))\nlow_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_low_z.pkl'.format(shape_cat,vol))\nhigh_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_high_z.pkl'.format(shape_cat,vol))\nlow_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_low_z.pkl'.format(shape_cat,vol))"}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'shape_cat': 'mcal', 'vol': 'vlim'},
#    'environment_variables': {},
#    'version': '1.2.0',
#    'input_path': '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
#    'output_path': '/home/cz136/project/sa/lib/output/data/mcal_vlim.ipynb',
#    'start_time': '2019-10-26T07:57:52.129126',
#    'end_time': '2019-10-26T08:27:12.820901',
#    'duration': 1760.691775,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/im3_all.ipynb',
   parameters = dict(shape_cat="im3",vol="all")
)
# Out:
# HBox(children=(IntProgress(value=0, description='Executing', max=71, style=ProgressStyle(description_width='in…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:14.154161',
#      'end_time': '2019-10-26T08:27:14.183212',
#      'duration': 0.029051,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_cat=""\nvol=""'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:14.208649',
#      'end_time': '2019-10-26T08:27:14.237692',
#      'duration': 0.029043,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\nshape_cat = "im3"\nvol = "all"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:14.260864',
#      'end_time': '2019-10-26T08:27:16.033367',
#      'duration': 1.772503,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'from astropy.io import fits\nfrom astropy.table import Table\nimport pandas as pd\nimport fitsio as fio\nimport numpy as np\nimport ast\n\nimport astropy.cosmology\nfrom astropy.coordinates import SkyCoord  # High-level coordinates\nfrom astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames\nfrom astropy.coordinates import Angle, Latitude, Longitude  # Angles\nimport astropy.units as u\nfrom IPython.display import display, Math'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:16.057978',
#      'end_time': '2019-10-26T08:27:16.755803',
#      'duration': 0.697825,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '809723\n16966\n5621\n'}],
#    'source': 'if vol=="vlim":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl50.fit\')[1].data)\nelif vol=="all":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl02.fit\')[1].data)\nelse:\n    raise TypeError("Wrong vol")\ncluster_table.remove_columns([\'P_C\',\'C_LAMBDA\',\'C_LAMBDA_ERR\',\'Q_CEN\']) #unknown columns\n\nprint(len(member_table))\nprint(len(cluster_table))\nprint(len(member_table[\'ID\'])-len(np.unique(member_table[\'ID\'])))'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:16.782386',
#      'end_time': '2019-10-26T08:27:53.433425',
#      'duration': 36.651039,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Metacal loaded\n'}],
#    'source': 'if shape_cat=="mcal":\n    mcal = fio.FITS(\'/lsst/troxel/y1a1/mcal-y1a1-combined-riz-unblind-v4-matched.fits\',memmap=True,mode=\'r\')[1]\n    print ("Metacal loaded")\n    shape_id=mcal[\'coadd_objects_id\'][:] \nelif shape_cat=="im3":\n        mcal = fio.FITS(\'/lsst/troxel/y1a1/y1a1-im3shape_v5_unblind_v2_matched_v4.fits\',memmap=True,mode=\'r\')[1]\n        print ("Metacal loaded")\n        shape_id=mcal[\'coadd_objects_id\'][:] \nelse:\n    raise '},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.460370',
#      'end_time': '2019-10-26T08:27:53.490608',
#      'duration': 0.030238,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "problem_list =['MODEL_MAG', 'MODEL_MAGERR', 'MAG_LAMBDA_ERR', 'PZBINS',\n               'PZ', 'RA_CENT', 'DEC_CENT', 'ID_CENT', 'LAMBDA_CHISQ_CENT',\n               'ZLAMBDA_CENT', 'P_BCG', 'P_CEN', 'P_FG', 'P_SAT']"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.518082',
#      'end_time': '2019-10-26T08:27:53.548957',
#      'duration': 0.030875,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'band_col_list = []\npz_col_list = []\nalt_col_list =[]\nfor problem in problem_list:\n    if cluster_table[problem].shape[1]==4:\n        band_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==5:\n        alt_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==21:\n        pz_col_list.append(problem)\n    else:\n        print ("error")'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.573901',
#      'end_time': '2019-10-26T08:27:53.605034',
#      'duration': 0.031133,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "band_list=['g','r','i','z','Y']\npz_index_list=['pz'+str(i+1) for i in range(21)]\nalt_index_list=['Alt'+str(i+1) for i in range(5)]"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.628930',
#      'end_time': '2019-10-26T08:27:53.669420',
#      'duration': 0.04049,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list):\n        cluster_table[str(('Band',band_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(band_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.697630',
#      'end_time': '2019-10-26T08:27:53.767893',
#      'duration': 0.070263,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(pz_col_list):\n    for j in range(21):\n        cluster_table[str(('PZ',pz_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(pz_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.795522',
#      'end_time': '2019-10-26T08:27:53.880162',
#      'duration': 0.08464,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(alt_col_list):\n    for j in range(5):\n        cluster_table[str(('Alt',alt_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(alt_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:53.907165',
#      'end_time': '2019-10-26T08:27:54.016048',
#      'duration': 0.108883,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "all_col_list=list(cluster_table.columns[0:54])\nfor i,column in enumerate(all_col_list):\n    cluster_table[str(('All','All',column))]=cluster_table[column].data[:]\ncluster_table.remove_columns(all_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:54.041137',
#      'end_time': '2019-10-26T08:27:54.107758',
#      'duration': 0.066621,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list[0:2]):\n        member_table['('+band_list[j]+','+column+')']=member_table[column].data[:,j]\nmember_table.remove_columns(band_col_list[0:2]) "},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:54.136287',
#      'end_time': '2019-10-26T08:27:54.837612',
#      'duration': 0.701325,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'clusters=cluster_table.to_pandas()\nmember=member_table.to_pandas()\nrandom=random_table.to_pandas()\n# center_table=None\n# member_table=None'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:54.863895',
#      'end_time': '2019-10-26T08:27:54.899742',
#      'duration': 0.035847,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_cols = member.columns[0:22]\nshape_columns=pd.MultiIndex.from_product([['All'],list(mcal.get_colnames())],names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:54.925856',
#      'end_time': '2019-10-26T08:27:54.957030',
#      'duration': 0.031174,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "center_bins=[m+str(n) for m,n in zip(['cen_']*5,np.arange(5)+1)]\ncenter=pd.MultiIndex.from_product([['Center'],center_bins,member_cols])"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:54.981516',
#      'end_time': '2019-10-26T08:27:55.011789',
#      'duration': 0.030273,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR','MAG_LAMBDA_ERR']],\n                                     names=['band','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.035972',
#      'end_time': '2019-10-26T08:27:55.063793',
#      'duration': 0.027821,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# alt_bins=[m+str(n) for m,n in zip(['alt_']*5,np.arange(5)+1)]\n# alt_columns=pd.MultiIndex.from_product([alt_bins,\n#                                        alt_col_list.append(shape_names)],\n#                                      names=['alt_index','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.089063',
#      'end_time': '2019-10-26T08:27:55.119817',
#      'duration': 0.030754,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR',]],\n                                     names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.143636',
#      'end_time': '2019-10-26T08:27:55.173485',
#      'duration': 0.029849,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_index=pd.MultiIndex.from_tuples([('MEM_MATCH_ID','TYPE')],names=['ClusterID','Type'])"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.198747',
#      'end_time': '2019-10-26T08:27:55.229219',
#      'duration': 0.030472,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random_columns=pd.MultiIndex.from_product([['All'],['RA', 'DEC', 'Z', 'LAMBDA_IN', 'AVG_LAMBDAOUT', 'SIGMA_LAMBDAOUT', 'WEIGHT']],\n                                       names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.253488',
#      'end_time': '2019-10-26T08:27:55.282028',
#      'duration': 0.02854,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'random.columns=random_columns'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.306878',
#      'end_time': '2019-10-26T08:27:55.335849',
#      'duration': 0.028971,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_id=member['ID'].values"},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.359344',
#      'end_time': '2019-10-26T08:27:55.387676',
#      'duration': 0.028332,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# for id in member_id:\n#     mask = pd.Series(shape_id)==id'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.412709',
#      'end_time': '2019-10-26T08:27:55.441638',
#      'duration': 0.028929,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_id_series = pd.Series(shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.465747',
#      'end_time': '2019-10-26T08:27:55.501983',
#      'duration': 0.036236,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def sort2n(x,y):\n    """\n    Sorts and matches two arrays of object ids where x is unique and y is not (in DES this is coadd_objects_id).\n    Slower than sort2().\n    """\n    \n    xsort = np.argsort(x)\n    ysort = np.argsort(y)\n    i_yx = np.sort(y[np.in1d(y, x, assume_unique=False)])\n    i_x = xsort[x[xsort].searchsorted(i_yx)]\n    i_y = ysort[y[ysort].searchsorted(i_yx)]\n    \n    return i_x, i_y'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:27:55.527739',
#      'end_time': '2019-10-26T08:28:26.351383',
#      'duration': 30.823644,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 's2n_index=sort2n(member_id,shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:26.381792',
#      'end_time': '2019-10-26T08:28:30.238861',
#      'duration': 3.857069,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_half=pd.DataFrame(mcal.read(rows=[s2n_index[1]]).byteswap().newbyteorder())'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.276786',
#      'end_time': '2019-10-26T08:28:30.488678',
#      'duration': 0.211892,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'member_half=member.iloc[s2n_index[0]]'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.520472',
#      'end_time': '2019-10-26T08:28:30.560877',
#      'duration': 0.040405,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_half_index=pd.MultiIndex.from_tuples(list(zip(['All']*23,member_half.columns[0:23]))+list(member_band_columns),names=['Band','Data']) "},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.588179',
#      'end_time': '2019-10-26T08:28:30.619002',
#      'duration': 0.030823,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_half.columns=shape_columns\nmember_half.columns=member_half_index\nshape_half.set_index(('All','coadd_objects_id'),inplace=True)\nmember_half.set_index(('All','ID'),inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.646620',
#      'end_time': '2019-10-26T08:28:30.852267',
#      'duration': 0.205647,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shapes=pd.concat([member_half,shape_half],axis=1,verify_integrity=True)\nshapes.index.name="ID"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.878751',
#      'end_time': '2019-10-26T08:28:30.903778',
#      'duration': 0.025027,
#      'status': 'completed'}},
#    'source': '# im3 e correction'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:28:30.928574',
#      'end_time': '2019-10-26T08:29:26.099916',
#      'duration': 55.171342,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'if shape_cat == "im3":\n    shapes[(\'All\',\'e1_old\')]=shapes[(\'All\',\'e1\')]\n    shapes[(\'All\',\'e2_old\')]=shapes[(\'All\',\'e2\')]\n    shapes[(\'All\',\'e1\')]=shapes.apply(lambda x:x[(\'All\',\'e1\')]-x[(\'All\',\'c1\')],axis=1)\n    shapes[(\'All\',\'e2\')]=shapes.apply(lambda x:x[(\'All\',\'e2\')]-x[(\'All\',\'c2\')],axis=1)'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:26.134864',
#      'end_time': '2019-10-26T08:29:26.176280',
#      'duration': 0.041416,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_col_list=[ast.literal_eval(name) for i,name in enumerate(clusters.columns)]\ncluster_col=pd.MultiIndex.from_tuples(cluster_col_list, names=['Type','Kind','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:26.200502',
#      'end_time': '2019-10-26T08:29:26.234861',
#      'duration': 0.034359,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.columns=cluster_col\nclusters.set_index(('All', 'All', 'MEM_MATCH_ID'),inplace=True);"},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:26.259701',
#      'end_time': '2019-10-26T08:29:26.295074',
#      'duration': 0.035373,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_theta_for_obj(obj1,obj2):\n    ra1,dec1=(obj1[('All', 'RA')],obj1[('All', 'DEC')])\n    ra2,dec2=(obj2[('All', 'RA')],obj2[('All', 'DEC')])\n    \n    \n    \n    c1=SkyCoord(ra1*u.deg,dec1*u.deg)\n    c2=SkyCoord(ra2*u.deg,dec2*u.deg)\n    \n    \n    return(90-c1.position_angle(c2).degree)"},
#   {'cell_type': 'code',
#    'execution_count': 37,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:26.318978',
#      'end_time': '2019-10-26T08:29:26.352306',
#      'duration': 0.033328,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_rel_theta(member):\n    cluster=clusters.loc[member[('All','MEM_MATCH_ID')]]\n    center=shapes.loc[cluster[('Alt','Alt1','ID_CENT')]]\n    theta=get_theta_for_obj(center,member)\n    return(theta)"},
#   {'cell_type': 'code',
#    'execution_count': 38,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:26.376804',
#      'end_time': '2019-10-26T08:29:54.378841',
#      'duration': 28.002037,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Added PP column.\n'}],
#    'source': 'shapes[(\'All\',\'PP\')]=shapes.apply(lambda x:x[(\'All\',\'P\')]*x[(\'All\',\'PFREE\')],axis=1)\nprint ("Added PP column.")'},
#   {'cell_type': 'code',
#    'execution_count': 39,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:54.408782',
#      'end_time': '2019-10-26T08:29:54.856921',
#      'duration': 0.448139,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes=shapes[shapes[('All', 'flags_select')]==0]\nshapes=shapes[shapes[('All','PP')]>=0.55]"},
#   {'cell_type': 'code',
#    'execution_count': 40,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:54.888532',
#      'end_time': '2019-10-26T08:29:55.002060',
#      'duration': 0.113528,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'The number of clusters with no center shape data 12230\nNumber of galaxies before masking: 157970\nNumber of galaxies after masking: 157970\nThe number of clusters with no center shape data 0\nNumber of galaxies before masking: 36654\nNumber of galaxies after masking: 36654\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: \nPassing list-likes to .loc or [] with any missing label will raise\nKeyError in the future, you can use .reindex() as an alternative.\n\nSee the documentation here:\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike\n  after removing the cwd from sys.path.\n'}],
#    'source': '# Drop clusters with no center\ndef drop_poor_centers():\n    center_id=clusters[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n    p=shapes.loc[center_id][(\'All\',\'P\')].to_numpy()\n    missing_mem_match_id=clusters[np.isnan(p)].index\n    clusters.drop(missing_mem_match_id,inplace=True)\n#     np.save("/home/cz136/project/sa/data/missing_centers.npy",center_id[np.isnan(p)].to_numpy())\n    print("The number of clusters with no center shape data {}".format(np.sum(np.isnan(p))))\ndrop_poor_centers()\n\n# Drop members with no cluster\ndef drop_poor_members():\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    return(valid_members)\n    \nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]\n\ndrop_poor_centers()\nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]'},
#   {'cell_type': 'code',
#    'execution_count': 41,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:29:55.030636',
#      'end_time': '2019-10-26T08:31:06.727905',
#      'duration': 71.697269,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:get_rel_theta(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 42,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:31:06.764178',
#      'end_time': '2019-10-26T08:31:10.471381',
#      'duration': 3.707203,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:360-x[('All','Theta_cen')] if x[('All','Theta_cen')]>=180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_cen')]=shapes.apply(lambda x:360+x[('All','Theta_cen')] if x[('All','Theta_cen')]<=-180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_sat')]=shapes.apply(lambda x:-(180-x[('All','Theta_cen')]) if x[('All','Theta_cen')]>=0 else (180+x[('All','Theta_cen')]),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 43,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:31:10.499702',
#      'end_time': '2019-10-26T08:31:10.536637',
#      'duration': 0.036935,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'H0=100 #km s-1 Mpc-1\nOm0=0.3\nOde0=0.7\nlcdm=astropy.cosmology.FlatLambdaCDM(H0, Om0)'},
#   {'cell_type': 'code',
#    'execution_count': 44,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:31:10.562375',
#      'end_time': '2019-10-26T08:38:54.643850',
#      'duration': 464.081475,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','angR')]=shapes.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)\nrandom[('All','angR')]=random.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:38:54.678949',
#      'end_time': '2019-10-26T08:38:54.704326',
#      'duration': 0.025377,
#      'status': 'completed'}},
#    'source': '# Add $\\phi$'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:38:54.729372',
#      'end_time': '2019-10-26T08:38:54.761784',
#      'duration': 0.032412,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_pa_for_member(obj):\n    e1=obj['All']['e1']\n    e2=obj['All']['e2']\n    \n    α =0.5*np.arctan2(-e2,-e1)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:38:54.788253',
#      'end_time': '2019-10-26T08:38:54.821159',
#      'duration': 0.032906,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'error_list_phi=[]\nerror_list_e=[]\n\ndef get_phi_for_member(member):\n    \n    """Input: cluster series\n        Output: an array of position angle weighted by PP\n        Record KeyError in an array (usually caused by uncomplete shape catalog).\n    """\n    \n    try:\n        cluster_id=member[(\'All\',\'MEM_MATCH_ID\')]\n        cluster=clusters.loc[cluster_id]\n        center_id=cluster[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n        center = shapes.loc[center_id]\n        \n        pa=get_pa_for_member(member)\n        theta= get_theta_for_obj(member,center)\n        phi=(pa-theta)\n    #     print(center.index)\n        return(phi)    \n    except KeyError as e:\n        error_list_phi.append(e)\n        print(e)\n        return(np.nan)'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:38:54.845746',
#      'end_time': '2019-10-26T08:40:27.346178',
#      'duration': 92.500432,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=shapes.apply(lambda x:get_phi_for_member(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:40:27.373096',
#      'end_time': '2019-10-26T08:40:27.404225',
#      'duration': 0.031129,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def process_phi(phi_1d):\n\n    phi_1d=np.where(phi_1d<=0,-phi_1d,phi_1d)\n    phi_1d=np.where(phi_1d>=180,phi_1d-180,phi_1d)\n    phi_1d=np.where(phi_1d>=90,180-phi_1d,phi_1d)\n\n    \n    return(phi_1d)'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:40:27.429467',
#      'end_time': '2019-10-26T08:40:27.466035',
#      'duration': 0.036568,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=process_phi(shapes[('All','phi')])"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:40:27.493104',
#      'end_time': '2019-10-26T08:40:27.518238',
#      'duration': 0.025134,
#      'status': 'completed'}},
#    'source': '# Add e'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:40:27.543459',
#      'end_time': '2019-10-26T08:40:27.578951',
#      'duration': 0.035492,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_e(sat):\n    cluster_id=sat[('All','MEM_MATCH_ID')]\n    cluster=clusters.loc[cluster_id]\n    center_id=cluster[('Alt', 'Alt1', 'ID_CENT')]\n    cen = shapes.loc[center_id]\n    \n    e=np.sqrt(sat[('All','e1')]**2+sat[('All','e2')]**2)\n    delta=get_theta_for_obj(cen,sat)\n    alpha=get_pa_for_member(sat)\n    ep,ex=(e*np.cos(2*(delta-alpha)),e*np.sin(2*(delta-alpha)))\n    return(ep,ex)"},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:40:27.605031',
#      'end_time': '2019-10-26T08:43:34.792127',
#      'duration': 187.187096,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','ep')]=shapes.apply(lambda x:get_e(x)[0],axis=1)\nshapes[('All','ex')]=shapes.apply(lambda x:get_e(x)[1],axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:43:34.836684',
#      'end_time': '2019-10-26T08:43:34.862211',
#      'duration': 0.025527,
#      'status': 'completed'}},
#    'source': '# Calculate cluster elipticity'},
#   {'cell_type': 'code',
#    'execution_count': 52,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:43:34.887002',
#      'end_time': '2019-10-26T08:43:34.923263',
#      'duration': 0.036261,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<IPython.core.display.Math object>',
#       'text/latex': '$\\displaystyle M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$'}}],
#    'source': 'display(Math(r"$M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$"))'},
#   {'cell_type': 'code',
#    'execution_count': 53,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:43:34.949659',
#      'end_time': '2019-10-26T08:43:34.990909',
#      'duration': 0.04125,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_Q_U(cluster):\n    \n    mem_match_id=cluster.name\n    members=shapes[shapes['All','MEM_MATCH_ID']==mem_match_id]\n    \n    members=members[members[('All','PP')]>=0.2]\n    \n    def get_M_for_cluster():\n        p = members[('All','PP')]\n        r = members[('All','R')]\n        pa = members[('All','Theta_cen')]\n        x = r * np.cos(pa)\n        y = r * np.sin(pa)\n        \n        def mom_2(p,x,y,r):\n            return(np.sum(p*x*y/r**2)/np.sum(p))\n        \n        Mxx=mom_2(p,x,x,r)\n        Mxy=mom_2(p,x,y,r)\n        Myy=mom_2(p,y,y,r)\n        return(Mxx,Mxy,Myy)\n\n    Mxx,Mxy,Myy=get_M_for_cluster()\n    Q,U=Mxx-Myy,2*Mxy\n    \n    return (Q,U)\n\n\ndef get_pa_from_Q_U(Q,U):\n    α =0.5*np.arctan2(U,Q)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 54,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:43:35.022946',
#      'end_time': '2019-10-26T08:44:09.308295',
#      'duration': 34.285349,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters[('All','All','Q')]=clusters.apply(lambda x:get_Q_U(x)[0],axis=1)\nclusters[('All','All','U')]=clusters.apply(lambda x:get_Q_U(x)[1],axis=1)\nclusters[('All','All','Beta')]=clusters.apply(lambda x:get_pa_from_Q_U(x[('All','All','Q')],x[('All','All','U')]),axis=1)\nclusters[('All','All','Ce')]=clusters.apply(lambda x:np.sqrt(x[('All','All','U')]**2+x[('All','All','U')]**2),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 55,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:09.340438',
#      'end_time': '2019-10-26T08:44:09.376540',
#      'duration': 0.036102,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_normLR(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    angR=shape[('All','angR')]\n    normR=angR/LR\n    return(normR)"},
#   {'cell_type': 'code',
#    'execution_count': 56,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:09.400948',
#      'end_time': '2019-10-26T08:44:20.435928',
#      'duration': 11.03498,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','normLR')]=shapes.apply(lambda x:get_normLR(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 57,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:20.468068',
#      'end_time': '2019-10-26T08:44:20.498852',
#      'duration': 0.030784,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def add_r_lambda(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    return(LR)"},
#   {'cell_type': 'code',
#    'execution_count': 58,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:20.523769',
#      'end_time': '2019-10-26T08:44:31.030099',
#      'duration': 10.50633,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','R_LAMBDA')]=shapes.apply(lambda x:add_r_lambda(x),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:31.062931',
#      'end_time': '2019-10-26T08:44:31.088654',
#      'duration': 0.025723,
#      'status': 'completed'}},
#    'source': '# Save'},
#   {'cell_type': 'code',
#    'execution_count': 59,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:31.113909',
#      'end_time': '2019-10-26T08:44:31.194920',
#      'duration': 0.081011,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 60,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:31.222926',
#      'end_time': '2019-10-26T08:44:31.356236',
#      'duration': 0.13331,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 61,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:31.385716',
#      'end_time': '2019-10-26T08:44:32.604643',
#      'duration': 1.218927,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random.to_pickle('/home/cz136/project/sa/data/{}/{}/random.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:32.655337',
#      'end_time': '2019-10-26T08:44:32.682868',
#      'duration': 0.027531,
#      'status': 'completed'}},
#    'source': '## z masking'},
#   {'cell_type': 'code',
#    'execution_count': 62,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:32.707540',
#      'end_time': '2019-10-26T08:44:32.737596',
#      'duration': 0.030056,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def drop_shapes_wo_cluster(clusters,shapes):\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    shapes=shapes[valid_members]\n    return(shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 63,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:32.763349',
#      'end_time': '2019-10-26T08:44:32.799759',
#      'duration': 0.03641,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z=clusters[clusters['All','All','Z_LAMBDA']>=0.35]\nlow_z=clusters[(clusters['All','All','Z_LAMBDA']<=0.35) & (clusters['All','All','Z_LAMBDA']>=0.1)]"},
#   {'cell_type': 'code',
#    'execution_count': 64,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:32.824225',
#      'end_time': '2019-10-26T08:44:32.869178',
#      'duration': 0.044953,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Number of galaxies before masking: 36654\nNumber of galaxies before masking: 36654\n'}],
#    'source': 'high_z_shapes=drop_shapes_wo_cluster(high_z,shapes)\nlow_z_shapes=drop_shapes_wo_cluster(low_z,shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 65,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:32.895006',
#      'end_time': '2019-10-26T08:44:33.038287',
#      'duration': 0.143281,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_high_z.pkl'.format(shape_cat,vol))\nlow_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_low_z.pkl'.format(shape_cat,vol))\nhigh_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_high_z.pkl'.format(shape_cat,vol))\nlow_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_low_z.pkl'.format(shape_cat,vol))"}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'shape_cat': 'im3', 'vol': 'all'},
#    'environment_variables': {},
#    'version': '1.2.0',
#    'input_path': '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
#    'output_path': '/home/cz136/project/sa/lib/output/data/im3_all.ipynb',
#    'start_time': '2019-10-26T08:27:12.934388',
#    'end_time': '2019-10-26T08:44:33.679418',
#    'duration': 1040.74503,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %%
pm.execute_notebook(
   '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
   '/home/cz136/project/sa/lib/output/data/im3_vlim.ipynb',
   parameters = dict(shape_cat="im3",vol="vlim")
)
# Out:
# HBox(children=(IntProgress(value=0, description='Executing', max=71, style=ProgressStyle(description_width='in…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:35.096024',
#      'end_time': '2019-10-26T08:44:35.129216',
#      'duration': 0.033192,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_cat=""\nvol=""'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:35.153717',
#      'end_time': '2019-10-26T08:44:35.182229',
#      'duration': 0.028512,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\nshape_cat = "im3"\nvol = "vlim"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:35.205131',
#      'end_time': '2019-10-26T08:44:36.950241',
#      'duration': 1.74511,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'from astropy.io import fits\nfrom astropy.table import Table\nimport pandas as pd\nimport fitsio as fio\nimport numpy as np\nimport ast\n\nimport astropy.cosmology\nfrom astropy.coordinates import SkyCoord  # High-level coordinates\nfrom astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames\nfrom astropy.coordinates import Angle, Latitude, Longitude  # Angles\nimport astropy.units as u\nfrom IPython.display import display, Math'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:36.981852',
#      'end_time': '2019-10-26T08:44:37.620498',
#      'duration': 0.638646,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '399002\n7066\n1427\n'}],
#    'source': 'if vol=="vlim":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17-vlim_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl50.fit\')[1].data)\nelif vol=="all":\n    cluster_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog.fit\')[1].data)\n    member_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3-d10-mof-001d_run_redmapper_v6.4.17_lgt20_desformat_catalog_members.fit\')[1].data)\n    random_table=Table(fits.open(\'/lsst/troxel/y1a1/y1a1_gold_1.0.3_wide+d10-mof-001d_run_redmapper_v6.4.17-2_randcat_z0.10-0.95_lgt020_vl02.fit\')[1].data)\nelse:\n    raise TypeError("Wrong vol")\ncluster_table.remove_columns([\'P_C\',\'C_LAMBDA\',\'C_LAMBDA_ERR\',\'Q_CEN\']) #unknown columns\n\nprint(len(member_table))\nprint(len(cluster_table))\nprint(len(member_table[\'ID\'])-len(np.unique(member_table[\'ID\'])))'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:37.652418',
#      'end_time': '2019-10-26T08:44:58.176798',
#      'duration': 20.52438,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Metacal loaded\n'}],
#    'source': 'if shape_cat=="mcal":\n    mcal = fio.FITS(\'/lsst/troxel/y1a1/mcal-y1a1-combined-riz-unblind-v4-matched.fits\',memmap=True,mode=\'r\')[1]\n    print ("Metacal loaded")\n    shape_id=mcal[\'coadd_objects_id\'][:] \nelif shape_cat=="im3":\n        mcal = fio.FITS(\'/lsst/troxel/y1a1/y1a1-im3shape_v5_unblind_v2_matched_v4.fits\',memmap=True,mode=\'r\')[1]\n        print ("Metacal loaded")\n        shape_id=mcal[\'coadd_objects_id\'][:] \nelse:\n    raise '},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.205311',
#      'end_time': '2019-10-26T08:44:58.240061',
#      'duration': 0.03475,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "problem_list =['MODEL_MAG', 'MODEL_MAGERR', 'MAG_LAMBDA_ERR', 'PZBINS',\n               'PZ', 'RA_CENT', 'DEC_CENT', 'ID_CENT', 'LAMBDA_CHISQ_CENT',\n               'ZLAMBDA_CENT', 'P_BCG', 'P_CEN', 'P_FG', 'P_SAT']"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.271062',
#      'end_time': '2019-10-26T08:44:58.309101',
#      'duration': 0.038039,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'band_col_list = []\npz_col_list = []\nalt_col_list =[]\nfor problem in problem_list:\n    if cluster_table[problem].shape[1]==4:\n        band_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==5:\n        alt_col_list.append(problem)\n    elif cluster_table[problem].shape[1]==21:\n        pz_col_list.append(problem)\n    else:\n        print ("error")'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.341272',
#      'end_time': '2019-10-26T08:44:58.376692',
#      'duration': 0.03542,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "band_list=['g','r','i','z','Y']\npz_index_list=['pz'+str(i+1) for i in range(21)]\nalt_index_list=['Alt'+str(i+1) for i in range(5)]"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.405519',
#      'end_time': '2019-10-26T08:44:58.451791',
#      'duration': 0.046272,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list):\n        cluster_table[str(('Band',band_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(band_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.481912',
#      'end_time': '2019-10-26T08:44:58.558329',
#      'duration': 0.076417,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(pz_col_list):\n    for j in range(21):\n        cluster_table[str(('PZ',pz_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(pz_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.585155',
#      'end_time': '2019-10-26T08:44:58.674074',
#      'duration': 0.088919,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for i,column in enumerate(alt_col_list):\n    for j in range(5):\n        cluster_table[str(('Alt',alt_index_list[j],column))]=cluster_table[column].data[:,j]\ncluster_table.remove_columns(alt_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.698797',
#      'end_time': '2019-10-26T08:44:58.811003',
#      'duration': 0.112206,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "all_col_list=list(cluster_table.columns[0:54])\nfor i,column in enumerate(all_col_list):\n    cluster_table[str(('All','All',column))]=cluster_table[column].data[:]\ncluster_table.remove_columns(all_col_list)"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.842731',
#      'end_time': '2019-10-26T08:44:58.906082',
#      'duration': 0.063351,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "for j in range(4):\n    for i,column in enumerate(band_col_list[0:2]):\n        member_table['('+band_list[j]+','+column+')']=member_table[column].data[:,j]\nmember_table.remove_columns(band_col_list[0:2]) "},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:58.933770',
#      'end_time': '2019-10-26T08:44:59.810035',
#      'duration': 0.876265,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'clusters=cluster_table.to_pandas()\nmember=member_table.to_pandas()\nrandom=random_table.to_pandas()\n# center_table=None\n# member_table=None'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:59.843494',
#      'end_time': '2019-10-26T08:44:59.885149',
#      'duration': 0.041655,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_cols = member.columns[0:22]\nshape_columns=pd.MultiIndex.from_product([['All'],list(mcal.get_colnames())],names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:59.912981',
#      'end_time': '2019-10-26T08:44:59.954319',
#      'duration': 0.041338,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "center_bins=[m+str(n) for m,n in zip(['cen_']*5,np.arange(5)+1)]\ncenter=pd.MultiIndex.from_product([['Center'],center_bins,member_cols])"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:44:59.984314',
#      'end_time': '2019-10-26T08:45:00.026551',
#      'duration': 0.042237,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR','MAG_LAMBDA_ERR']],\n                                     names=['band','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.055998',
#      'end_time': '2019-10-26T08:45:00.090599',
#      'duration': 0.034601,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# alt_bins=[m+str(n) for m,n in zip(['alt_']*5,np.arange(5)+1)]\n# alt_columns=pd.MultiIndex.from_product([alt_bins,\n#                                        alt_col_list.append(shape_names)],\n#                                      names=['alt_index','data'])"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.119323',
#      'end_time': '2019-10-26T08:45:00.160836',
#      'duration': 0.041513,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_band_columns=pd.MultiIndex.from_product([['g','r','i','z'],\n                                       ['MODEL_MAG','MODEL_MAGERR',]],\n                                     names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.191897',
#      'end_time': '2019-10-26T08:45:00.227171',
#      'duration': 0.035274,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_index=pd.MultiIndex.from_tuples([('MEM_MATCH_ID','TYPE')],names=['ClusterID','Type'])"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.252179',
#      'end_time': '2019-10-26T08:45:00.291748',
#      'duration': 0.039569,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random_columns=pd.MultiIndex.from_product([['All'],['RA', 'DEC', 'Z', 'LAMBDA_IN', 'AVG_LAMBDAOUT', 'SIGMA_LAMBDAOUT', 'WEIGHT']],\n                                       names=['Band','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.316454',
#      'end_time': '2019-10-26T08:45:00.349333',
#      'duration': 0.032879,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'random.columns=random_columns'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.375044',
#      'end_time': '2019-10-26T08:45:00.404018',
#      'duration': 0.028974,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_id=member['ID'].values"},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.427975',
#      'end_time': '2019-10-26T08:45:00.458497',
#      'duration': 0.030522,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# for id in member_id:\n#     mask = pd.Series(shape_id)==id'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.487367',
#      'end_time': '2019-10-26T08:45:00.520019',
#      'duration': 0.032652,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_id_series = pd.Series(shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.547107',
#      'end_time': '2019-10-26T08:45:00.585284',
#      'duration': 0.038177,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def sort2n(x,y):\n    """\n    Sorts and matches two arrays of object ids where x is unique and y is not (in DES this is coadd_objects_id).\n    Slower than sort2().\n    """\n    \n    xsort = np.argsort(x)\n    ysort = np.argsort(y)\n    i_yx = np.sort(y[np.in1d(y, x, assume_unique=False)])\n    i_x = xsort[x[xsort].searchsorted(i_yx)]\n    i_y = ysort[y[ysort].searchsorted(i_yx)]\n    \n    return i_x, i_y'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:00.614232',
#      'end_time': '2019-10-26T08:45:33.463975',
#      'duration': 32.849743,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 's2n_index=sort2n(member_id,shape_id)'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:33.496886',
#      'end_time': '2019-10-26T08:45:35.173571',
#      'duration': 1.676685,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shape_half=pd.DataFrame(mcal.read(rows=[s2n_index[1]]).byteswap().newbyteorder())'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.204201',
#      'end_time': '2019-10-26T08:45:35.307774',
#      'duration': 0.103573,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'member_half=member.iloc[s2n_index[0]]'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.338355',
#      'end_time': '2019-10-26T08:45:35.378056',
#      'duration': 0.039701,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "member_half_index=pd.MultiIndex.from_tuples(list(zip(['All']*23,member_half.columns[0:23]))+list(member_band_columns),names=['Band','Data']) "},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.403716',
#      'end_time': '2019-10-26T08:45:35.439804',
#      'duration': 0.036088,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shape_half.columns=shape_columns\nmember_half.columns=member_half_index\nshape_half.set_index(('All','coadd_objects_id'),inplace=True)\nmember_half.set_index(('All','ID'),inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.467924',
#      'end_time': '2019-10-26T08:45:35.582611',
#      'duration': 0.114687,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'shapes=pd.concat([member_half,shape_half],axis=1,verify_integrity=True)\nshapes.index.name="ID"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.619524',
#      'end_time': '2019-10-26T08:45:35.644357',
#      'duration': 0.024833,
#      'status': 'completed'}},
#    'source': '# im3 e correction'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:45:35.668413',
#      'end_time': '2019-10-26T08:46:02.207302',
#      'duration': 26.538889,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'if shape_cat == "im3":\n    shapes[(\'All\',\'e1_old\')]=shapes[(\'All\',\'e1\')]\n    shapes[(\'All\',\'e2_old\')]=shapes[(\'All\',\'e2\')]\n    shapes[(\'All\',\'e1\')]=shapes.apply(lambda x:x[(\'All\',\'e1\')]-x[(\'All\',\'c1\')],axis=1)\n    shapes[(\'All\',\'e2\')]=shapes.apply(lambda x:x[(\'All\',\'e2\')]-x[(\'All\',\'c2\')],axis=1)'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:02.239710',
#      'end_time': '2019-10-26T08:46:02.282818',
#      'duration': 0.043108,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cluster_col_list=[ast.literal_eval(name) for i,name in enumerate(clusters.columns)]\ncluster_col=pd.MultiIndex.from_tuples(cluster_col_list, names=['Type','Kind','Data'])"},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:02.309416',
#      'end_time': '2019-10-26T08:46:02.347806',
#      'duration': 0.03839,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.columns=cluster_col\nclusters.set_index(('All', 'All', 'MEM_MATCH_ID'),inplace=True);"},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:02.379296',
#      'end_time': '2019-10-26T08:46:02.415529',
#      'duration': 0.036233,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_theta_for_obj(obj1,obj2):\n    ra1,dec1=(obj1[('All', 'RA')],obj1[('All', 'DEC')])\n    ra2,dec2=(obj2[('All', 'RA')],obj2[('All', 'DEC')])\n    \n    \n    \n    c1=SkyCoord(ra1*u.deg,dec1*u.deg)\n    c2=SkyCoord(ra2*u.deg,dec2*u.deg)\n    \n    \n    return(90-c1.position_angle(c2).degree)"},
#   {'cell_type': 'code',
#    'execution_count': 37,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:02.444675',
#      'end_time': '2019-10-26T08:46:02.478458',
#      'duration': 0.033783,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_rel_theta(member):\n    cluster=clusters.loc[member[('All','MEM_MATCH_ID')]]\n    center=shapes.loc[cluster[('Alt','Alt1','ID_CENT')]]\n    theta=get_theta_for_obj(center,member)\n    return(theta)"},
#   {'cell_type': 'code',
#    'execution_count': 38,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:02.503916',
#      'end_time': '2019-10-26T08:46:15.605859',
#      'duration': 13.101943,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Added PP column.\n'}],
#    'source': 'shapes[(\'All\',\'PP\')]=shapes.apply(lambda x:x[(\'All\',\'P\')]*x[(\'All\',\'PFREE\')],axis=1)\nprint ("Added PP column.")'},
#   {'cell_type': 'code',
#    'execution_count': 39,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:15.632556',
#      'end_time': '2019-10-26T08:46:15.872833',
#      'duration': 0.240277,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes=shapes[shapes[('All', 'flags_select')]==0]\nshapes=shapes[shapes[('All','PP')]>=0.55]"},
#   {'cell_type': 'code',
#    'execution_count': 40,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:15.899091',
#      'end_time': '2019-10-26T08:46:15.965485',
#      'duration': 0.066394,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'The number of clusters with no center shape data 6421\nNumber of galaxies before masking: 96828\nNumber of galaxies after masking: 96828\nThe number of clusters with no center shape data 0\nNumber of galaxies before masking: 10072\nNumber of galaxies after masking: 10072\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/home/cz136/anaconda3/envs/balrog/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: \nPassing list-likes to .loc or [] with any missing label will raise\nKeyError in the future, you can use .reindex() as an alternative.\n\nSee the documentation here:\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike\n  after removing the cwd from sys.path.\n'}],
#    'source': '# Drop clusters with no center\ndef drop_poor_centers():\n    center_id=clusters[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n    p=shapes.loc[center_id][(\'All\',\'P\')].to_numpy()\n    missing_mem_match_id=clusters[np.isnan(p)].index\n    clusters.drop(missing_mem_match_id,inplace=True)\n#     np.save("/home/cz136/project/sa/data/missing_centers.npy",center_id[np.isnan(p)].to_numpy())\n    print("The number of clusters with no center shape data {}".format(np.sum(np.isnan(p))))\ndrop_poor_centers()\n\n# Drop members with no cluster\ndef drop_poor_members():\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    return(valid_members)\n    \nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]\n\ndrop_poor_centers()\nvalid_members_id=drop_poor_members()\nprint("Number of galaxies after masking: {}".format(len(shapes)))\nshapes=shapes[valid_members_id]'},
#   {'cell_type': 'code',
#    'execution_count': 41,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:15.991327',
#      'end_time': '2019-10-26T08:46:35.543253',
#      'duration': 19.551926,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:get_rel_theta(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 42,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:35.574852',
#      'end_time': '2019-10-26T08:46:36.587551',
#      'duration': 1.012699,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','Theta_cen')]=shapes.apply(lambda x:360-x[('All','Theta_cen')] if x[('All','Theta_cen')]>=180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_cen')]=shapes.apply(lambda x:360+x[('All','Theta_cen')] if x[('All','Theta_cen')]<=-180 else x[('All','Theta_cen')],axis=1)\nshapes[('All','Theta_sat')]=shapes.apply(lambda x:-(180-x[('All','Theta_cen')]) if x[('All','Theta_cen')]>=0 else (180+x[('All','Theta_cen')]),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 43,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:36.616334',
#      'end_time': '2019-10-26T08:46:36.647595',
#      'duration': 0.031261,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'H0=100 #km s-1 Mpc-1\nOm0=0.3\nOde0=0.7\nlcdm=astropy.cosmology.FlatLambdaCDM(H0, Om0)'},
#   {'cell_type': 'code',
#    'execution_count': 44,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:46:36.671971',
#      'end_time': '2019-10-26T08:53:08.429902',
#      'duration': 391.757931,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','angR')]=shapes.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)\nrandom[('All','angR')]=random.apply(lambda x:np.float(lcdm.angular_diameter_distance(x[('All','Z')])/u.Mpc),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:08.461925',
#      'end_time': '2019-10-26T08:53:08.487377',
#      'duration': 0.025452,
#      'status': 'completed'}},
#    'source': '# Add $\\phi$'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:08.511943',
#      'end_time': '2019-10-26T08:53:08.548767',
#      'duration': 0.036824,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_pa_for_member(obj):\n    e1=obj['All']['e1']\n    e2=obj['All']['e2']\n    \n    α =0.5*np.arctan2(-e2,-e1)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:08.580389',
#      'end_time': '2019-10-26T08:53:08.612686',
#      'duration': 0.032297,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'error_list_phi=[]\nerror_list_e=[]\n\ndef get_phi_for_member(member):\n    \n    """Input: cluster series\n        Output: an array of position angle weighted by PP\n        Record KeyError in an array (usually caused by uncomplete shape catalog).\n    """\n    \n    try:\n        cluster_id=member[(\'All\',\'MEM_MATCH_ID\')]\n        cluster=clusters.loc[cluster_id]\n        center_id=cluster[(\'Alt\', \'Alt1\', \'ID_CENT\')]\n        center = shapes.loc[center_id]\n        \n        pa=get_pa_for_member(member)\n        theta= get_theta_for_obj(member,center)\n        phi=(pa-theta)\n    #     print(center.index)\n        return(phi)    \n    except KeyError as e:\n        error_list_phi.append(e)\n        print(e)\n        return(np.nan)'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:08.637417',
#      'end_time': '2019-10-26T08:53:34.014673',
#      'duration': 25.377256,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=shapes.apply(lambda x:get_phi_for_member(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:34.044874',
#      'end_time': '2019-10-26T08:53:34.083152',
#      'duration': 0.038278,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def process_phi(phi_1d):\n\n    phi_1d=np.where(phi_1d<=0,-phi_1d,phi_1d)\n    phi_1d=np.where(phi_1d>=180,phi_1d-180,phi_1d)\n    phi_1d=np.where(phi_1d>=90,180-phi_1d,phi_1d)\n\n    \n    return(phi_1d)'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:34.112135',
#      'end_time': '2019-10-26T08:53:34.142711',
#      'duration': 0.030576,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','phi')]=process_phi(shapes[('All','phi')])"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:34.168462',
#      'end_time': '2019-10-26T08:53:34.193655',
#      'duration': 0.025193,
#      'status': 'completed'}},
#    'source': '# Add e'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:34.218329',
#      'end_time': '2019-10-26T08:53:34.256166',
#      'duration': 0.037837,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_e(sat):\n    cluster_id=sat[('All','MEM_MATCH_ID')]\n    cluster=clusters.loc[cluster_id]\n    center_id=cluster[('Alt', 'Alt1', 'ID_CENT')]\n    cen = shapes.loc[center_id]\n    \n    e=np.sqrt(sat[('All','e1')]**2+sat[('All','e2')]**2)\n    delta=get_theta_for_obj(cen,sat)\n    alpha=get_pa_for_member(sat)\n    ep,ex=(e*np.cos(2*(delta-alpha)),e*np.sin(2*(delta-alpha)))\n    return(ep,ex)"},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:53:34.284288',
#      'end_time': '2019-10-26T08:54:26.027100',
#      'duration': 51.742812,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','ep')]=shapes.apply(lambda x:get_e(x)[0],axis=1)\nshapes[('All','ex')]=shapes.apply(lambda x:get_e(x)[1],axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:26.056701',
#      'end_time': '2019-10-26T08:54:26.088383',
#      'duration': 0.031682,
#      'status': 'completed'}},
#    'source': '# Calculate cluster elipticity'},
#   {'cell_type': 'code',
#    'execution_count': 52,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:26.113359',
#      'end_time': '2019-10-26T08:54:26.154585',
#      'duration': 0.041226,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<IPython.core.display.Math object>',
#       'text/latex': '$\\displaystyle M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$'}}],
#    'source': 'display(Math(r"$M_{\\mathrm{xx}} \\equiv\\left\\langle\\frac{x^{2}}{r^{2}}\\right\\rangle=\\frac{\\sum_{i} p_{\\mathrm{mem}, i} \\frac{x_{i}^{2}}{r_{i}^{2}}}{\\sum_{i} p_{\\mathrm{mem}, i}}$"))'},
#   {'cell_type': 'code',
#    'execution_count': 53,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:26.186667',
#      'end_time': '2019-10-26T08:54:26.229337',
#      'duration': 0.04267,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_Q_U(cluster):\n    \n    mem_match_id=cluster.name\n    members=shapes[shapes['All','MEM_MATCH_ID']==mem_match_id]\n    \n    members=members[members[('All','PP')]>=0.2]\n    \n    def get_M_for_cluster():\n        p = members[('All','PP')]\n        r = members[('All','R')]\n        pa = members[('All','Theta_cen')]\n        x = r * np.cos(pa)\n        y = r * np.sin(pa)\n        \n        def mom_2(p,x,y,r):\n            return(np.sum(p*x*y/r**2)/np.sum(p))\n        \n        Mxx=mom_2(p,x,x,r)\n        Mxy=mom_2(p,x,y,r)\n        Myy=mom_2(p,y,y,r)\n        return(Mxx,Mxy,Myy)\n\n    Mxx,Mxy,Myy=get_M_for_cluster()\n    Q,U=Mxx-Myy,2*Mxy\n    \n    return (Q,U)\n\n\ndef get_pa_from_Q_U(Q,U):\n    α =0.5*np.arctan2(U,Q)*180/np.pi\n    return(α)"},
#   {'cell_type': 'code',
#    'execution_count': 54,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:26.254009',
#      'end_time': '2019-10-26T08:54:31.079031',
#      'duration': 4.825022,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters[('All','All','Q')]=clusters.apply(lambda x:get_Q_U(x)[0],axis=1)\nclusters[('All','All','U')]=clusters.apply(lambda x:get_Q_U(x)[1],axis=1)\nclusters[('All','All','Beta')]=clusters.apply(lambda x:get_pa_from_Q_U(x[('All','All','Q')],x[('All','All','U')]),axis=1)\nclusters[('All','All','Ce')]=clusters.apply(lambda x:np.sqrt(x[('All','All','U')]**2+x[('All','All','U')]**2),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 55,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:31.107537',
#      'end_time': '2019-10-26T08:54:31.139903',
#      'duration': 0.032366,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def get_normLR(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    angR=shape[('All','angR')]\n    normR=angR/LR\n    return(normR)"},
#   {'cell_type': 'code',
#    'execution_count': 56,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:31.165496',
#      'end_time': '2019-10-26T08:54:34.187879',
#      'duration': 3.022383,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','normLR')]=shapes.apply(lambda x:get_normLR(x),axis=1)"},
#   {'cell_type': 'code',
#    'execution_count': 57,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:34.220286',
#      'end_time': '2019-10-26T08:54:34.256845',
#      'duration': 0.036559,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def add_r_lambda(shape):\n    cluster_id=shape[('All','MEM_MATCH_ID')]\n    LR = clusters.loc[cluster_id][('All','All','R_LAMBDA')]\n    return(LR)"},
#   {'cell_type': 'code',
#    'execution_count': 58,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:34.287734',
#      'end_time': '2019-10-26T08:54:37.125497',
#      'duration': 2.837763,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes[('All','R_LAMBDA')]=shapes.apply(lambda x:add_r_lambda(x),axis=1)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:37.160057',
#      'end_time': '2019-10-26T08:54:37.185623',
#      'duration': 0.025566,
#      'status': 'completed'}},
#    'source': '# Save'},
#   {'cell_type': 'code',
#    'execution_count': 59,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:37.211027',
#      'end_time': '2019-10-26T08:54:37.265484',
#      'duration': 0.054457,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "clusters.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 60,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:37.291597',
#      'end_time': '2019-10-26T08:54:37.354176',
#      'duration': 0.062579,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'code',
#    'execution_count': 61,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:37.379719',
#      'end_time': '2019-10-26T08:54:38.393165',
#      'duration': 1.013446,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "random.to_pickle('/home/cz136/project/sa/data/{}/{}/random.pkl'.format(shape_cat,vol))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:38.440507',
#      'end_time': '2019-10-26T08:54:38.466383',
#      'duration': 0.025876,
#      'status': 'completed'}},
#    'source': '## z masking'},
#   {'cell_type': 'code',
#    'execution_count': 62,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:38.490647',
#      'end_time': '2019-10-26T08:54:38.520971',
#      'duration': 0.030324,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'def drop_shapes_wo_cluster(clusters,shapes):\n    valid_clusters_id=clusters.index.to_numpy()\n    shapes_match_id=shapes[(\'All\',\'MEM_MATCH_ID\')].to_numpy()\n    print("Number of galaxies before masking: {}".format(len(shapes_match_id)))\n    valid_members=np.isin(shapes_match_id,valid_clusters_id)\n    shapes=shapes[valid_members]\n    return(shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 63,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:38.546594',
#      'end_time': '2019-10-26T08:54:38.581761',
#      'duration': 0.035167,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z=clusters[clusters['All','All','Z_LAMBDA']>=0.35]\nlow_z=clusters[(clusters['All','All','Z_LAMBDA']<=0.35) & (clusters['All','All','Z_LAMBDA']>=0.1)]"},
#   {'cell_type': 'code',
#    'execution_count': 64,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:38.606438',
#      'end_time': '2019-10-26T08:54:38.642657',
#      'duration': 0.036219,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Number of galaxies before masking: 10072\nNumber of galaxies before masking: 10072\n'}],
#    'source': 'high_z_shapes=drop_shapes_wo_cluster(high_z,shapes)\nlow_z_shapes=drop_shapes_wo_cluster(low_z,shapes)'},
#   {'cell_type': 'code',
#    'execution_count': 65,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-10-26T08:54:38.668818',
#      'end_time': '2019-10-26T08:54:38.739636',
#      'duration': 0.070818,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "high_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_high_z.pkl'.format(shape_cat,vol))\nlow_z.to_pickle('/home/cz136/project/sa/data/{}/{}/clusters_low_z.pkl'.format(shape_cat,vol))\nhigh_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_high_z.pkl'.format(shape_cat,vol))\nlow_z_shapes.to_pickle('/home/cz136/project/sa/data/{}/{}/shapes_low_z.pkl'.format(shape_cat,vol))"}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'shape_cat': 'im3', 'vol': 'vlim'},
#    'environment_variables': {},
#    'version': '1.2.0',
#    'input_path': '/home/cz136/project/sa/lib/src/data_marshalling.ipynb',
#    'output_path': '/home/cz136/project/sa/lib/output/data/im3_vlim.ipynb',
#    'start_time': '2019-10-26T08:44:33.862560',
#    'end_time': '2019-10-26T08:54:39.376715',
#    'duration': 605.514155,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %% [markdown]
# # Analysis

# %%
for shape in shape_list:
    for vol in vol_list:
        for z in z_list:
            pm.execute_notebook(
               '/home/cz136/project/sa/lib/src/phi_e_sat.ipynb',
               '/home/cz136/project/sa/lib/output/{}/{}/{}/phi_e_sat.ipynb'.format(shape,vol,z),
               parameters = dict(shape_cat=shape,vol=vol,z_range=z)
            )

# %%
for shape in shape_list:
    for vol_ in vol_list:
        for z in z_list:
            pm.execute_notebook(
               '/home/cz136/project/sa/lib/src/treecorr_cross.ipynb',
               '/home/cz136/project/sa/lib/output/{}/{}/{}/treecorr_{}_{}_{}.ipynb'.format(shape,vol_,z,shape,vol_,z),
               parameters = dict(shape_cat=shape,vol=vol_,z_range=z)
            )
# Out:
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Executing', max=25, style=ProgressStyle(description_width='in…
