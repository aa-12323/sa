# %%
shape_measurement=""
z_range=""
vol=""

# %%
#This header file contains all the common packages
# %matplotlib inline
# %run ./header.ipynb

# %%
print(len(clusters))
print(len(shapes))
# Out:
# 12482
# 203070

# %%
# Print the numbers of galaxies that needed to be masked

print(np.sum(shapes[('All','e1')]==-9999))
print(np.sum(shapes[('All','e2')]==-9999))
print(np.sum(shapes['All','flags_select']==0))
print(np.sum(shapes[('All','PP')]<=0.55))
# Out:
# 0
# 0
# 203070
# 0

# %%
#masking
print(len(clusters))
print(len(shapes))
# Out:
# 12482
# 203070

# %% [markdown]
# # Stats of e1,e2

# %%
from matplotlib.colors import LogNorm 
plt.hist2d(shapes['All','e1'],shapes['All','e2'],bins=500,norm=LogNorm())
plt.axis('equal')
plt.title("2D Histogram of $e_1$ and $e_2$")
pd.Series(shapes['All','e1']).describe()
pd.Series(shapes['All','e2']).describe()
# Out:
# count    203070.000000
# mean         -0.000320
# std           0.147964
# min          -0.728444
# 25%          -0.080939
# 50%          -0.000233
# 75%           0.080106
# max           0.852003
# Name: (All, e2), dtype: float64

# %%
#statistics and hisgoram of e2/e1
plt.hist(shapes['All','e2']/shapes['All','e1'],bins=np.arange(-10,10,0.1))
plt.title("Histogram of $e_2$/$e_1$")
pd.Series(shapes['All','e2']/shapes['All','e1']).describe()
# Out:
# count    203070.000000
# mean          0.668877
# std         274.120513
# min      -44173.333800
# 25%          -1.006517
# 50%           0.000047
# 75%           0.998770
# max       67310.028672
# dtype: float64

# %% [markdown]
# # Get phi

# %%
def get_std_err_of_mean(np_array):
    mean=np_array.mean()
    std=np_array.std()
    n=len(np_array)
    return(std/np.sqrt(n))

# %% [markdown]
# ## Stats for weighted

# %%
pd.Series(phi_w_1d).describe()
print("Mean:{:05e} \nStdE:{:05e} ".format(phi_1d.mean(),phi_1d.std()/np.sqrt(len(phi_1d))))
# Out:
# Mean:4.524490e+01
# StdE:5.718271e-02

# %%
BINS=np.arange(0,90,1)
ax = sns.distplot(shapes[('All','phi')],bins=BINS,kde=False,hist_kws={'weights':shapes[('All','PP')]})
ax.set_title("Histogram of $\phi_{sat}$ weighted by probability") 
pd.Series(phi_w_1d).describe()
# Out:
# count    203070.000000
# mean         45.244898
# std          25.768473
# min           0.000277
# 25%          22.500000
# 50%          45.390314
# 75%          67.500000
# max          89.999729
# dtype: float64

# %% [markdown]
# ## Stats for unweighted

# %%
pd.Series(phi_w_1d).describe()
print("Mean:{:05e} \nStdE:{:05e} ".format(phi_1d.mean(),phi_1d.std()/np.sqrt(len(phi_1d))))
# Out:
# Mean:4.524490e+01
# StdE:5.718271e-02

# %%
BINS=np.arange(0,90,1)
ax = sns.distplot(shapes[('All','phi')],bins=BINS,kde=False)
ax.set_title("Histogram of $\phi_{sat}$ weighted by probability") 
pd.Series(phi_w_1d).describe()
# Out:
# count    203070.000000
# mean         45.244898
# std          25.768473
# min           0.000277
# 25%          22.500000
# 50%          45.390314
# 75%          67.500000
# max          89.999729
# dtype: float64

# %%
np.sum((shapes[('All','phi')]>=22.4) &(shapes[('All','phi')]<=22.6)) 
abn_1 = shapes[(shapes[('All','phi')]>=22.4) &(shapes[('All','phi')]<=22.6)]
abn_2 = shapes[(shapes[('All','phi')]>67.4) &(shapes[('All','phi')]<=67.6)]

# %%
corr_1=abn_1.corr(method='pearson')[('All','phi')]
corr_2=abn_2.corr(method='pearson')[('All','phi')]

# %%
print(corr_1.to_string())
print(corr_2.to_string())
# Out:
# Band  Data
# All   MEM_MATCH_ID      -0.035468
#       Z                 -0.115308
#       RA                -0.358160
#       DEC                0.033408
#       R                  0.016937
#       P                  0.006602
#       PFREE             -0.016656
#       THETA_I            0.002600
#       THETA_R           -0.018426
#       REFMAG_FIT        -0.068796
#       REFMAG_FIT_E      -0.070082
#       REFMAG            -0.068796
#       REFMAG_ERR        -0.070082
#       ZRED              -0.107906
#       ZRED_E            -0.046158
#       ZRED2             -0.107410
#       ZRED2_E           -0.066011
#       CHISQ             -0.004255
#       EBV                     NaN
#       ZSPEC                   NaN
#       ZMAG              -0.068796
#       ZMAG_ERR          -0.070082
# g     MODEL_MAG         -0.089318
#       MODEL_MAGERR      -0.072896
# r     MODEL_MAG         -0.091134
#       MODEL_MAGERR      -0.091398
# i     MODEL_MAG         -0.077250
#       MODEL_MAGERR      -0.072606
# z     MODEL_MAG         -0.068796
#       MODEL_MAGERR      -0.070082
# All   flags                   NaN
#       mask_frac         -0.012077
#       psf_e1             0.045750
#       psf_e2             0.110155
#       psf_size          -0.126112
#       mcal_psf_e1        0.043688
#       mcal_psf_e2       -0.023205
#       mcal_psf_size     -0.116034
#       e1                 0.009991
#       e1_1p              0.009878
#       e1_1m              0.009984
#       e1_2p              0.009698
#       e1_2m              0.010010
#       e2                 0.007756
#       e2_1p              0.008373
#       e2_1m              0.007814
#       e2_2p              0.007806
#       e2_2m              0.007913
#       size              -0.028239
#       size_1p           -0.028776
#       size_1m           -0.029400
#       size_2p           -0.028700
#       size_2m           -0.028854
#       size_err          -0.016919
#       size_err_1p       -0.016944
#       size_err_1m       -0.020381
#       size_err_2p       -0.021258
#       size_err_2m       -0.016624
#       snr                0.053615
#       snr_1p             0.053613
#       snr_1m             0.053603
#       snr_2p             0.053598
#       snr_2m             0.053620
#       covmat_0_0        -0.041226
#       covmat_0_0_1p     -0.030246
#       covmat_0_0_1m     -0.030139
#       covmat_0_0_2p     -0.036876
#       covmat_0_0_2m     -0.017968
#       covmat_0_1        -0.011375
#       covmat_0_1_1p     -0.002478
#       covmat_0_1_1m     -0.002639
#       covmat_0_1_2p     -0.004222
#       covmat_0_1_2m     -0.005227
#       covmat_1_1        -0.040540
#       covmat_1_1_1p     -0.024607
#       covmat_1_1_1m     -0.029654
#       covmat_1_1_2p     -0.037811
#       covmat_1_1_2m     -0.017547
#       flux_r             0.049121
#       flux_r_1p          0.049102
#       flux_r_1m          0.049073
#       flux_r_2p          0.049082
#       flux_r_2m          0.049122
#       flux_err_r         0.022463
#       flux_i             0.045482
#       flux_i_1p          0.045453
#       flux_i_1m          0.045426
#       flux_i_2p          0.045439
#       flux_i_2m          0.045475
#       flux_err_i         0.035067
#       flux_z             0.041849
#       flux_z_1p          0.041802
#       flux_z_1m          0.041781
#       flux_z_2p          0.041783
#       flux_z_2m          0.041830
#       flux_err_z         0.020790
#       R11               -0.002255
#       R12               -0.007597
#       R21                0.011956
#       R22               -0.002091
#       region                  NaN
#       ra                -0.358160
#       dec                0.033408
#       flags_select            NaN
#       flags_select_1p   -0.021792
#       flags_select_1m   -0.015207
#       flags_select_2p   -0.040347
#       flags_select_2m    0.000304
#       PP                 0.005621
#       Theta_cen         -0.012938
#       Theta_sat          0.025759
#       angR              -0.108689
#       normR              0.018978
#       phi                1.000000
# Band  Data
# All   MEM_MATCH_ID      -0.030642
#       Z                  0.128674
#       RA                -0.319022
#       DEC                0.032764
#       R                 -0.012039
#       P                  0.014254
#       PFREE              0.009768
#       THETA_I           -0.007450
#       THETA_R            0.006647
#       REFMAG_FIT         0.083845
#       REFMAG_FIT_E       0.080387
#       REFMAG             0.083845
#       REFMAG_ERR         0.080387
#       ZRED               0.119269
#       ZRED_E             0.063653
#       ZRED2              0.120193
#       ZRED2_E            0.093143
#       CHISQ              0.001143
#       EBV                     NaN
#       ZSPEC             -0.001186
#       ZMAG               0.083845
#       ZMAG_ERR           0.080387
# g     MODEL_MAG          0.102632
#       MODEL_MAGERR       0.076119
# r     MODEL_MAG          0.104115
#       MODEL_MAGERR       0.099801
# i     MODEL_MAG          0.100296
#       MODEL_MAGERR       0.105228
# z     MODEL_MAG          0.083845
#       MODEL_MAGERR       0.080387
# All   flags                   NaN
#       mask_frac          0.006689
#       psf_e1             0.076127
#       psf_e2             0.073951
#       psf_size          -0.113417
#       mcal_psf_e1       -0.043283
#       mcal_psf_e2        0.007786
#       mcal_psf_size     -0.092567
#       e1                -0.007288
#       e1_1p             -0.008183
#       e1_1m             -0.005860
#       e1_2p             -0.006207
#       e1_2m             -0.007365
#       e2                -0.014642
#       e2_1p             -0.014809
#       e2_1m             -0.014546
#       e2_2p             -0.014761
#       e2_2m             -0.014924
#       size              -0.009753
#       size_1p           -0.009539
#       size_1m           -0.008786
#       size_2p           -0.009831
#       size_2m           -0.010116
#       size_err           0.038947
#       size_err_1p        0.034203
#       size_err_1m        0.035703
#       size_err_2p        0.031504
#       size_err_2m        0.031523
#       snr               -0.061245
#       snr_1p            -0.061236
#       snr_1m            -0.061247
#       snr_2p            -0.061242
#       snr_2m            -0.061249
#       covmat_0_0         0.042274
#       covmat_0_0_1p      0.043583
#       covmat_0_0_1m      0.044013
#       covmat_0_0_2p      0.026630
#       covmat_0_0_2m      0.024615
#       covmat_0_1         0.002562
#       covmat_0_1_1p      0.005762
#       covmat_0_1_1m      0.012351
#       covmat_0_1_2p      0.004906
#       covmat_0_1_2m      0.005035
#       covmat_1_1         0.036862
#       covmat_1_1_1p      0.042618
#       covmat_1_1_1m      0.044210
#       covmat_1_1_2p      0.023487
#       covmat_1_1_2m      0.018194
#       flux_r            -0.055452
#       flux_r_1p         -0.055477
#       flux_r_1m         -0.055466
#       flux_r_2p         -0.055469
#       flux_r_2m         -0.055525
#       flux_err_r        -0.054030
#       flux_i            -0.058501
#       flux_i_1p         -0.058522
#       flux_i_1m         -0.058469
#       flux_i_2p         -0.058497
#       flux_i_2m         -0.058563
#       flux_err_i        -0.059825
#       flux_z            -0.054397
#       flux_z_1p         -0.054416
#       flux_z_1m         -0.054360
#       flux_z_2p         -0.054384
#       flux_z_2m         -0.054468
#       flux_err_z        -0.048580
#       R11               -0.036796
#       R12                0.023448
#       R21               -0.004838
#       R22                0.003140
#       region                  NaN
#       ra                -0.319022
#       dec                0.032764
#       flags_select            NaN
#       flags_select_1p    0.012528
#       flags_select_1m    0.000549
#       flags_select_2p    0.021221
#       flags_select_2m    0.000425
#       PP                 0.015249
#       Theta_cen          0.010267
#       Theta_sat          0.005407
#       angR               0.111831
#       normR             -0.025933
#       phi                1.000000

# %%
shapes[('All','region')].describe()
shapes[('All','region')].hist()

# %%
abn_1[('All','RA')].hist()
#RA of objects with ϕ=22.5

# %%
abn_2[('All','RA')].hist()
#RA of objects with ϕ=67.5

# %%
shapes[('All','RA')].hist()
#RA of all objects

# %%
abn_1_Coor=SkyCoord(abn_1['All','RA'],abn_1['All','DEC'],unit=u.deg)
abn_2_Coor=SkyCoord(abn_2['All','RA'],abn_2['All','DEC'],unit=u.deg)
shape_Coor=SkyCoord(shapes['All','RA'],shapes['All','DEC'],unit=u.deg)


plt.figure()
plt.subplot(111, projection="mollweide")
plt.title("Mollweide")
plt.grid(True)
plt.scatter(shape_Coor.ra.radian, shape_Coor.dec.radian,color='y')
plt.scatter(abn_1_Coor.ra.radian, abn_1_Coor.dec.radian,color='r')
plt.scatter(abn_2_Coor.ra.radian, abn_2_Coor.dec.radian,color='m')
plt.show()

# %%
np.save("/home/cz136/project/sa/data/mcal_225_id.npy",abn_1.index.to_numpy())
np.save("/home/cz136/project/sa/data/mcal_675_id.npy",abn_2.index.to_numpy())
np.save("/home/cz136/project/sa/data/mcal_225_ra.npy",abn_1[('All','ra')].to_numpy())
np.save("/home/cz136/project/sa/data/mcal_225_dec.npy",abn_1[('All','dec')].to_numpy())
np.save("/home/cz136/project/sa/data/mcal_675_ra.npy",abn_2[('All','ra')].to_numpy())
np.save("/home/cz136/project/sa/data/mcal_675_dec.npy",abn_2[('All','dec')].to_numpy())

# %%
abn_1
# Out:
# Band                All                                                      \
# Data       MEM_MATCH_ID         Z         RA        DEC         R         P
# ID
# 3051808954         7389  0.821791  74.854305 -43.826264  0.399891  0.851992
# 3051808992         7389  0.821791  74.855796 -43.825542  0.424056  0.727406
# 3051809599         7389  0.821791  74.870697 -43.815548  0.693031  0.666025
# 3051809653         7389  0.821791  74.782808 -43.814973  0.708856  0.635817
# 3051814686        36063  0.880051  74.912589 -43.739271  0.581941  0.681659
# ...                 ...       ...        ...        ...       ...       ...
# 3058376042        10341  0.693250  70.201805 -50.089310  0.203495  0.884291
# 3058376205         2417  0.398909  70.669093 -44.214674  0.820893  0.608165
# 3058377411        10341  0.693250  70.219209 -50.087550  0.000000  1.000000
# 3058378075         2417  0.398909  70.665890 -44.212440  0.791871  0.702123
# 3058378119         2417  0.398909  70.691582 -44.211606  0.805573  0.719179
#
# Band                                           ...                  \
# Data       PFREE THETA_I   THETA_R REFMAG_FIT  ... flags_select_1p
# ID                                             ...
# 3051808954   1.0     1.0  1.000000  19.674402  ...               0
# 3051808992   1.0     1.0  1.000000  22.006842  ...               0
# 3051809599   1.0     1.0  0.998579  21.270115  ...               0
# 3051809653   1.0     1.0  0.996182  20.768747  ...               0
# 3051814686   1.0     1.0  0.998980  21.237314  ...               0
# ...          ...     ...       ...        ...  ...             ...
# 3058376042   1.0     1.0  1.000000  21.372423  ...               0
# 3058376205   1.0     1.0  0.757486  20.577759  ...               0
# 3058377411   1.0     1.0  1.000000  19.048391  ...               0
# 3058378075   1.0     1.0  0.899495  18.247475  ...               0
# 3058378119   1.0     1.0  0.842464  18.841215  ...               0
#
# Band                                                                  \
# Data       flags_select_1m flags_select_2p flags_select_2m        PP
# ID
# 3051808954               0               0               0  0.851992
# 3051808992               0               0               0  0.727406
# 3051809599               0               0               0  0.666025
# 3051809653               0               0               0  0.635817
# 3051814686               0               0               0  0.681659
# ...                    ...             ...             ...       ...
# 3058376042               0               0               0  0.884291
# 3058376205               0               0               0  0.608165
# 3058377411               0               0               0  1.000000
# 3058378075               0               0               0  0.702123
# 3058378119               0               0               0  0.719179
#
# Band
# Data         Theta_cen   Theta_sat         angR     normR        phi
# ID
# 3051808954   20.564898 -159.435102  1093.890262  0.316529  22.400360
# 3051808992   21.334648 -158.665352  1093.890262  0.335656  22.401491
# 3051809599   29.896188 -150.103812  1093.890262  0.548560  22.401802
# 3051809653  149.813554  -30.186446  1093.890262  0.561086  22.402238
# 3051814686  -41.475933  138.524067  1117.584609  0.527005  22.402382
# ...                ...         ...          ...       ...        ...
# 3058376042 -171.036365    8.963635  1027.752487  0.178890  22.598628
# 3058376205  -90.971225   89.028775   774.483132  0.639470  22.598672
# 3058377411   90.000000  -90.000000  1027.752487  0.000000  22.599755
# 3058378075  -93.252685   86.747315   774.483132  0.616862  22.599904
# 3058378119  -75.341559  104.658441   774.483132  0.627536  22.599978
#
# [6645 rows x 115 columns]

# %% [markdown]
# # Analysis around 22.5 and 67.5

# %%
#Print out the most crowded bins

phi_count=np.histogram(phi_1d,bins=BINS)
sort=np.argsort(-phi_count[0])
print(phi_count[1][sort])
print(phi_count[0][sort])

# %%
#Statistics around 22.5
first_cluster_left=np.sum(phi_count[0][0:22])
first_length=phi_count[0][sort][0]
first_cluster=phi_1d[first_cluster_left:first_cluster_left+first_length]
ax = sns.distplot(first_cluster,kde=False)
ax.set_title("$\phi_{sat}$ Distribution Around 22.5 $\degree$")
pd.Series(first_cluster).describe()

# %%
second_cluster_left=np.sum(phi_count[0][0:67])
second_length=phi_count[0][sort][0]
second_cluster=phi_1d[second_cluster_left:second_cluster_left+second_length]
ax = sns.distplot(second_cluster,kde=False)
ax.set_title("$\phi_{sat}$ Distribution Around 67.5 $\degree$")
pd.Series(second_cluster).describe()

# %% [markdown]
# # Get e

# %% [markdown]
# ## Statistics of e1 and e2

# %%
e1=shapes[('All','e1')].to_numpy()
shapes[('All','e1')].describe()

# %%
e2=shapes[('All','e1')].to_numpy()
shapes[('All','e2')].describe()

# %%
def get_e_for_pair(cen,sat):
    e=np.sqrt(sat[('All','e1')]**2+sat[('All','e2')]**2)
    delta=get_theta_for_obj(cen,sat)
    alpha=get_pa_for_obj(sat)
    ep,ex=(e*np.cos(2*(delta-alpha)),e*np.sin(2*(delta-alpha)))
    return(ep,ex)

# %%
def get_e_for_cluster(cluster):
    
    try:
        center_id=cluster[('Alt', 'Alt1', 'ID_CENT')]
        center = shapes.loc[center_id]

        mem_match_id=cluster.name
        members=shapes[shapes['All','MEM_MATCH_ID']==mem_match_id]

        e_array=np.array([(get_e_for_pair(center,member[1])) for member in members.iterrows()])
        return(e_array)    
    except KeyError as e:
        error_list_e.append(e)
        return(np.array([]))

# %%
e_list=[]
for mem_matching_id in tqdm(clusters.index[:]):
    e_array=get_e_for_cluster(clusters.loc[mem_matching_id])
    e_list.append(e_array)
e_list=np.array(e_list)
e_list=np.concatenate([e_array for e_array in e_list if e_array!=np.array([])])

# %%
np.save("/home/cz136/project/sa/data/{}/e_array".format(dir_string),e_list)

# %%
e_p_1d=e_list[:,0].flatten()
e_x_1d=e_list[:,1].flatten()

# %%
ax=sns.distplot(e_p_1d,kde=False)
ax.set_title("Distribution of $e_{+}$")
print ("mean={:05e}, std_mean={:05e}".format(e_p_1d.mean(),get_std_err_of_mean(e_p_1d)))
pd.Series(e_p_1d).describe()

# %%
ax=sns.distplot(e_x_1d)
ax.set_title("Distribution of $e_{x}$")
print ("mean={:05e}, std_mean={:05e}".format(e_x_1d.mean(),get_std_err_of_mean(e_x_1d)))
pd.Series(e_x_1d).describe()
